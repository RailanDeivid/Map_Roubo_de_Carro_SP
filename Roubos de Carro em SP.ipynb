# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import geopandas as gp
import glob
import folium
import os
from folium.plugins import MarkerCluster
from shapely.geometry import Polygon, Point, LineString, MultiPolygon

# %% [markdown]
# # Importando dados

# %% [markdown]
# * Carregando todos os arquivos de uma só vez e concatenando em um df principal

# %%
path = 'data/'                     
todos_arquivos = glob.glob(os.path.join(path, "*.csv"))    

dfs = (pd.read_csv(arquivo, usecols=['DATAOCORRENCIA', 'PERIDOOCORRENCIA','LOGRADOURO', 'NUMERO', 'CIDADE', 
                                     'UF', 'LATITUDE', 'LONGITUDE', 'PLACA_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO', 
                                     'ANO_MODELO', 'DESCR_TIPO_VEICULO'], 
                   sep=";", decimal=',', encoding='latin1') for arquivo in todos_arquivos)

df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ## Verificando Base de Dados

# %%
#Visualizando as 5 primeiras linhas 
df.head()
# Out:
#   DATAOCORRENCIA PERIDOOCORRENCIA                       LOGRADOURO  NUMERO  \
# 0     31/12/2020          A NOITE  RUA PROCÓPIO BARBOSA DE MIRANDA     128
# 1     31/12/2020          A NOITE    RUA DOUTOR JOSE PEREIRA GOMES    1627
# 2     31/12/2020          A NOITE         AVENIDA GABRIELA MISTRAL      95
# 3     31/12/2020          A NOITE                   RODOVIA SP 324     520
# 4     31/12/2020          A NOITE                 RUA DOCE VITORIA       5
#
#             CIDADE  UF   LATITUDE  LONGITUDE PLACA_VEICULO DESCR_COR_VEICULO  \
# 0  ITAQUAQUECETUBA  SP -23.464688 -46.316572       DRW2B37             Verde
# 1        SÃO PAULO  SP -23.496574 -46.372711       EZP9F19             Cinza
# 2        SÃO PAULO  SP -23.516960 -46.549701       DRL4572            Branco
# 3         CAMPINAS  SP -23.024741 -47.125820       QMU9905             Prata
# 4        SÃO PAULO  SP -23.567778 -46.418146       FAY7731             Prata
#
#        DESCR_MARCA_VEICULO  ANO_MODELO DESCR_TIPO_VEICULO
# 0          YAMAHA/YBR 125K         NaN          MOTOCICLO
# 1      FORD/KA SE 1.0 HA C         NaN          AUTOMOVEL
# 2    RENAULT/KWID ZEN 10MT      2020.0          AUTOMOVEL
# 3          RENAULT/SANDERO         NaN          AUTOMOVEL
# 4  CHEVROLET/ONIX 1.4MT LT      2015.0          AUTOMOVEL

# %%
# Verificando tamanho da base de dados
print('{} Linhas e {} colunas'.format(df.shape[0], df.shape[1]))
# Out:
# 37702 Linhas e 13 colunas

# %%
df.dtypes
# Out:
# DATAOCORRENCIA          object
# PERIDOOCORRENCIA        object
# LOGRADOURO              object
# NUMERO                   int64
# CIDADE                  object
# UF                      object
# LATITUDE               float64
# LONGITUDE              float64
# PLACA_VEICULO           object
# DESCR_COR_VEICULO       object
# DESCR_MARCA_VEICULO     object
# ANO_MODELO             float64
# DESCR_TIPO_VEICULO      object
# dtype: object

# %% [markdown]
# * Alterando os tipos de colunas

# %%
df[['NUMERO', 'ANO_MODELO']] = df[['NUMERO', 'ANO_MODELO']].astype('object')

# %%
df.dtypes
# Out:
# DATAOCORRENCIA          object
# PERIDOOCORRENCIA        object
# LOGRADOURO              object
# NUMERO                  object
# CIDADE                  object
# UF                      object
# LATITUDE               float64
# LONGITUDE              float64
# PLACA_VEICULO           object
# DESCR_COR_VEICULO       object
# DESCR_MARCA_VEICULO     object
# ANO_MODELO              object
# DESCR_TIPO_VEICULO      object
# dtype: object

# %% [markdown]
# * Verificando se há dados faltantes

# %%
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# Quantidade de dados nulos: 48842

# %%
 df.isna().sum()
# Out:
# DATAOCORRENCIA             0
# PERIDOOCORRENCIA           0
# LOGRADOURO                 0
# NUMERO                     0
# CIDADE                     0
# UF                         0
# LATITUDE                   0
# LONGITUDE                  0
# PLACA_VEICULO          10852
# DESCR_COR_VEICULO       9708
# DESCR_MARCA_VEICULO    10665
# ANO_MODELO              7909
# DESCR_TIPO_VEICULO      9708
# dtype: int64

# %% [markdown]
# ### Decisão sobre os dados Ausentes.

# %% [markdown]
# * Como os dados faltantes se tratam de uma informção sobre o veiculo roubado, não faz sentido remover eses dados.
# * Diante disso irei apenas atribuir 'Não informando' a esses dados faltantes.

# %%
df.fillna( 'NÃO INFORMADO', inplace=True)
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# Quantidade de dados nulos: 0

# %% [markdown]
# # Plotando Mapas

# %% [markdown]
# * Carregando dados de geometria que serão usados para plotagem de mapas

# %%
import shapefile

# %%
#importando arquivo com a geometria dos estado
uf_sp = gpd.read_file('mapas/ESTADOS/35UFE250GC_SIR.shp')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7008/3472436302.py in <module>
#       1 #importando arquivo com a geometria dos estado
# ----> 2 uf_sp = gpd.read_file('mapas/ESTADOS/35UFE250GC_SIR.shp')
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     164     by using the encoding keyword parameter, e.g. ``encoding='utf-8'``.
#     165     """
# --> 166     _check_fiona("'read_file' function")
#     167     filename = _expand_user(filename)
#     168
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _check_fiona(func)
#      78 def _check_fiona(func):
#      79     if fiona is None:
# ---> 80         raise ImportError(
#      81             f"the {func} requires the 'fiona' package, but it is not installed or does "
#      82             f"not import correctly.\nImporting fiona resulted in: {fiona_import_error}"
#
# ImportError: the 'read_file' function requires the 'fiona' package, but it is not installed or does not import correctly.
# Importing fiona resulted in: DLL load failed while importing ogrext: Não foi possível encontrar o procedimento especificado.

# %%
uf_sp

# %% [markdown]
# ## Transformando DataFrame em GeoDataDrame

# %%
# filtrando apenas a localização
lat_long = list(zip(df.LATITUDE, df.LONGITUDE))
lat_long
# Out:
# [(-23.464688, -46.3165719),
#  (-23.49657433, -46.37271051),
#  (-23.51696043, -46.54970075),
#  (-23.02474138, -47.12582018),
#  (-23.56777787, -46.41814619),
#  (-23.52918892, -46.47812736),
#  (-23.66183562, -46.68918967),
#  (-23.5007773, -46.4068532),
#  (-22.95027249, -47.11010612),
#  (-23.28905472, -46.58138454),
#  (-23.44291361, -46.75513232),
#  (-23.44195965, -47.05765119),
#  (-23.44195965, -47.05765119),
#  (-23.44195965, -47.05765119),
#  (-23.44195965, -47.05765119),
#  (-23.44594626, -46.58110753),
#  (-23.44953178, -46.50563445),
#  (-22.74118227, -47.62972232),
#  (-22.74118227, -47.62972232),
#  (-22.74118227, -47.62972232),
#  (-22.74118227, -47.62972232),
#  (-21.96473117, -46.8287407),
#  (-23.53575518, -46.8336784),
#  (-23.6587101, -46.701719),
#  (-23.6587101, -46.701719),
#  (-23.6581202, -46.42501959),
#  (-23.07479115, -45.65114204),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.38553034, -46.74351624),
#  ...]

# %%
#transformando em pontos geometricos
geometry = [Point(x) for x in lat_long]
geometry
# Out:
# [<shapely.geometry.point.Point at 0x179993bb070>,
#  <shapely.geometry.point.Point at 0x17996e406d0>,
#  <shapely.geometry.point.Point at 0x17999360370>,
#  <shapely.geometry.point.Point at 0x17996e41880>,
#  <shapely.geometry.point.Point at 0x17996e41d00>,
#  <shapely.geometry.point.Point at 0x179861c6eb0>,
#  <shapely.geometry.point.Point at 0x179993bb670>,
#  <shapely.geometry.point.Point at 0x179993bb100>,
#  <shapely.geometry.point.Point at 0x179993bb160>,
#  <shapely.geometry.point.Point at 0x179993bb5b0>,
#  <shapely.geometry.point.Point at 0x179993bb970>,
#  <shapely.geometry.point.Point at 0x17996e93430>,
#  <shapely.geometry.point.Point at 0x179993bb760>,
#  <shapely.geometry.point.Point at 0x179993bba60>,
#  <shapely.geometry.point.Point at 0x179993bba00>,
#  <shapely.geometry.point.Point at 0x179993bba90>,
#  <shapely.geometry.point.Point at 0x179993bb820>,
#  <shapely.geometry.point.Point at 0x179993bb460>,
#  <shapely.geometry.point.Point at 0x179993bb880>,
#  <shapely.geometry.point.Point at 0x179993bb550>,
#  <shapely.geometry.point.Point at 0x179993bb430>,
#  <shapely.geometry.point.Point at 0x179993bb610>,
#  <shapely.geometry.point.Point at 0x179993bb580>,
#  <shapely.geometry.point.Point at 0x179993bb6a0>,
#  <shapely.geometry.point.Point at 0x179993bb400>,
#  <shapely.geometry.point.Point at 0x179993bb0d0>,
#  <shapely.geometry.point.Point at 0x179993bbac0>,
#  <shapely.geometry.point.Point at 0x179993bbb20>,
#  <shapely.geometry.point.Point at 0x179993bbb80>,
#  <shapely.geometry.point.Point at 0x179993bbbe0>,
#  <shapely.geometry.point.Point at 0x179993bbc40>,
#  <shapely.geometry.point.Point at 0x179993bbca0>,
#  <shapely.geometry.point.Point at 0x179993bbd00>,
#  <shapely.geometry.point.Point at 0x179993bbd60>,
#  <shapely.geometry.point.Point at 0x179993602b0>,
#  <shapely.geometry.point.Point at 0x179993608b0>,
#  <shapely.geometry.point.Point at 0x17999360ee0>,
#  <shapely.geometry.point.Point at 0x179993bbdf0>,
#  <shapely.geometry.point.Point at 0x179993bbe50>,
#  <shapely.geometry.point.Point at 0x179993bbeb0>,
#  <shapely.geometry.point.Point at 0x179993bbf10>,
#  <shapely.geometry.point.Point at 0x179993bbf70>,
#  <shapely.geometry.point.Point at 0x179993bbfd0>,
#  <shapely.geometry.point.Point at 0x179984b1070>,
#  <shapely.geometry.point.Point at 0x179984b10d0>,
#  <shapely.geometry.point.Point at 0x179984b1130>,
#  <shapely.geometry.point.Point at 0x179984b1190>,
#  <shapely.geometry.point.Point at 0x179984b11f0>,
#  <shapely.geometry.point.Point at 0x179984b1250>,
#  <shapely.geometry.point.Point at 0x179984b12b0>,
#  <shapely.geometry.point.Point at 0x179984b1310>,
#  <shapely.geometry.point.Point at 0x179984b1370>,
#  <shapely.geometry.point.Point at 0x179984b13d0>,
#  <shapely.geometry.point.Point at 0x179984b1430>,
#  <shapely.geometry.point.Point at 0x179984b1490>,
#  <shapely.geometry.point.Point at 0x179984b14f0>,
#  <shapely.geometry.point.Point at 0x179984b1550>,
#  <shapely.geometry.point.Point at 0x179984b15b0>,
#  <shapely.geometry.point.Point at 0x179984b1610>,
#  <shapely.geometry.point.Point at 0x179984b1670>,
#  <shapely.geometry.point.Point at 0x179984b16d0>,
#  <shapely.geometry.point.Point at 0x179984b1730>,
#  <shapely.geometry.point.Point at 0x179984b1790>,
#  <shapely.geometry.point.Point at 0x179984b17f0>,
#  <shapely.geometry.point.Point at 0x179984b1850>,
#  <shapely.geometry.point.Point at 0x179984b18b0>,
#  <shapely.geometry.point.Point at 0x179984b1910>,
#  <shapely.geometry.point.Point at 0x179984b1970>,
#  <shapely.geometry.point.Point at 0x179984b19d0>,
#  <shapely.geometry.point.Point at 0x179984b1a30>,
#  <shapely.geometry.point.Point at 0x179984b1a90>,
#  <shapely.geometry.point.Point at 0x179984b1af0>,
#  <shapely.geometry.point.Point at 0x179984b1b50>,
#  <shapely.geometry.point.Point at 0x179984b1bb0>,
#  <shapely.geometry.point.Point at 0x179984b1c10>,
#  <shapely.geometry.point.Point at 0x179984b1c70>,
#  <shapely.geometry.point.Point at 0x179984b1cd0>,
#  <shapely.geometry.point.Point at 0x179984b1d30>,
#  <shapely.geometry.point.Point at 0x179984b1d90>,
#  <shapely.geometry.point.Point at 0x179984b1df0>,
#  <shapely.geometry.point.Point at 0x179984b1e50>,
#  <shapely.geometry.point.Point at 0x179984b1eb0>,
#  <shapely.geometry.point.Point at 0x179984b1f10>,
#  <shapely.geometry.point.Point at 0x17999360b50>,
#  <shapely.geometry.point.Point at 0x179984b1fa0>,
#  <shapely.geometry.point.Point at 0x17999ce8040>,
#  <shapely.geometry.point.Point at 0x17999ce80a0>,
#  <shapely.geometry.point.Point at 0x17999ce8100>,
#  <shapely.geometry.point.Point at 0x17999ce8160>,
#  <shapely.geometry.point.Point at 0x17999ce81c0>,
#  <shapely.geometry.point.Point at 0x17999ce8220>,
#  <shapely.geometry.point.Point at 0x17999ce8280>,
#  <shapely.geometry.point.Point at 0x17999ce82e0>,
#  <shapely.geometry.point.Point at 0x17999ce8340>,
#  <shapely.geometry.point.Point at 0x17999ce83a0>,
#  <shapely.geometry.point.Point at 0x17999ce8400>,
#  <shapely.geometry.point.Point at 0x17999ce8460>,
#  <shapely.geometry.point.Point at 0x17999ce84c0>,
#  <shapely.geometry.point.Point at 0x17999ce8520>,
#  <shapely.geometry.point.Point at 0x17999ce8580>,
#  <shapely.geometry.point.Point at 0x17999ce85e0>,
#  <shapely.geometry.point.Point at 0x17999ce8640>,
#  <shapely.geometry.point.Point at 0x17999ce86a0>,
#  <shapely.geometry.point.Point at 0x17999ce8700>,
#  <shapely.geometry.point.Point at 0x17999ce8760>,
#  <shapely.geometry.point.Point at 0x17999ce87c0>,
#  <shapely.geometry.point.Point at 0x17999ce8820>,
#  <shapely.geometry.point.Point at 0x17999ce8880>,
#  <shapely.geometry.point.Point at 0x17999ce88e0>,
#  <shapely.geometry.point.Point at 0x17999ce8940>,
#  <shapely.geometry.point.Point at 0x17999ce89a0>,
#  <shapely.geometry.point.Point at 0x17999ce8a00>,
#  <shapely.geometry.point.Point at 0x17999ce8a60>,
#  <shapely.geometry.point.Point at 0x17999ce8ac0>,
#  <shapely.geometry.point.Point at 0x17999ce8b20>,
#  <shapely.geometry.point.Point at 0x17999ce8b80>,
#  <shapely.geometry.point.Point at 0x17999ce8be0>,
#  <shapely.geometry.point.Point at 0x17999ce8c40>,
#  <shapely.geometry.point.Point at 0x17999ce8ca0>,
#  <shapely.geometry.point.Point at 0x17999ce8d00>,
#  <shapely.geometry.point.Point at 0x17999ce8d60>,
#  <shapely.geometry.point.Point at 0x17999ce8dc0>,
#  <shapely.geometry.point.Point at 0x17999ce8e20>,
#  <shapely.geometry.point.Point at 0x17999ce8e80>,
#  <shapely.geometry.point.Point at 0x17999ce8ee0>,
#  <shapely.geometry.point.Point at 0x17999ce8f40>,
#  <shapely.geometry.point.Point at 0x17999ce8fa0>,
#  <shapely.geometry.point.Point at 0x17999cea040>,
#  <shapely.geometry.point.Point at 0x17999cea0a0>,
#  <shapely.geometry.point.Point at 0x17999cea100>,
#  <shapely.geometry.point.Point at 0x17999cea160>,
#  <shapely.geometry.point.Point at 0x17999cea1c0>,
#  <shapely.geometry.point.Point at 0x17999cea220>,
#  <shapely.geometry.point.Point at 0x17999cea280>,
#  <shapely.geometry.point.Point at 0x17999cea2e0>,
#  <shapely.geometry.point.Point at 0x17999cea340>,
#  <shapely.geometry.point.Point at 0x17999cea3a0>,
#  <shapely.geometry.point.Point at 0x17999cea400>,
#  <shapely.geometry.point.Point at 0x17999cea460>,
#  <shapely.geometry.point.Point at 0x17999cea4c0>,
#  <shapely.geometry.point.Point at 0x17999cea520>,
#  <shapely.geometry.point.Point at 0x17999cea580>,
#  <shapely.geometry.point.Point at 0x17999cea5e0>,
#  <shapely.geometry.point.Point at 0x17999cea640>,
#  <shapely.geometry.point.Point at 0x17999cea6a0>,
#  <shapely.geometry.point.Point at 0x17999cea700>,
#  <shapely.geometry.point.Point at 0x17999cea760>,
#  <shapely.geometry.point.Point at 0x17999cea7c0>,
#  <shapely.geometry.point.Point at 0x17999cea820>,
#  <shapely.geometry.point.Point at 0x17999cea880>,
#  <shapely.geometry.point.Point at 0x17999cea8e0>,
#  <shapely.geometry.point.Point at 0x17999cea940>,
#  <shapely.geometry.point.Point at 0x17999cea9a0>,
#  <shapely.geometry.point.Point at 0x17999ceaa00>,
#  <shapely.geometry.point.Point at 0x17999ceaa60>,
#  <shapely.geometry.point.Point at 0x17999ceaac0>,
#  <shapely.geometry.point.Point at 0x17999ceab20>,
#  <shapely.geometry.point.Point at 0x17999ceab80>,
#  <shapely.geometry.point.Point at 0x17999ceabe0>,
#  <shapely.geometry.point.Point at 0x17999ceac40>,
#  <shapely.geometry.point.Point at 0x17999ceaca0>,
#  <shapely.geometry.point.Point at 0x17999cead00>,
#  <shapely.geometry.point.Point at 0x17999cead60>,
#  <shapely.geometry.point.Point at 0x17999ceadc0>,
#  <shapely.geometry.point.Point at 0x17999ceae20>,
#  <shapely.geometry.point.Point at 0x17999ceae80>,
#  <shapely.geometry.point.Point at 0x17999ceaee0>,
#  <shapely.geometry.point.Point at 0x17999ceaf40>,
#  <shapely.geometry.point.Point at 0x17999ceafa0>,
#  <shapely.geometry.point.Point at 0x17999cec040>,
#  <shapely.geometry.point.Point at 0x17999cec0a0>,
#  <shapely.geometry.point.Point at 0x17999cec100>,
#  <shapely.geometry.point.Point at 0x17999cec160>,
#  <shapely.geometry.point.Point at 0x17999cec1c0>,
#  <shapely.geometry.point.Point at 0x17999cec220>,
#  <shapely.geometry.point.Point at 0x17999cec280>,
#  <shapely.geometry.point.Point at 0x17999cec2e0>,
#  <shapely.geometry.point.Point at 0x17999cec340>,
#  <shapely.geometry.point.Point at 0x17999cec3a0>,
#  <shapely.geometry.point.Point at 0x17999cec400>,
#  <shapely.geometry.point.Point at 0x17999cec460>,
#  <shapely.geometry.point.Point at 0x17999cec4c0>,
#  <shapely.geometry.point.Point at 0x17999cec520>,
#  <shapely.geometry.point.Point at 0x17999cec580>,
#  <shapely.geometry.point.Point at 0x17999cec5e0>,
#  <shapely.geometry.point.Point at 0x17999cec640>,
#  <shapely.geometry.point.Point at 0x17999cec6a0>,
#  <shapely.geometry.point.Point at 0x17999cec700>,
#  <shapely.geometry.point.Point at 0x17999cec760>,
#  <shapely.geometry.point.Point at 0x17999cec7c0>,
#  <shapely.geometry.point.Point at 0x17999cec820>,
#  <shapely.geometry.point.Point at 0x17999cec880>,
#  <shapely.geometry.point.Point at 0x17999cec8e0>,
#  <shapely.geometry.point.Point at 0x17999cec940>,
#  <shapely.geometry.point.Point at 0x17999cec9a0>,
#  <shapely.geometry.point.Point at 0x17999ceca00>,
#  <shapely.geometry.point.Point at 0x17999ceca60>,
#  <shapely.geometry.point.Point at 0x17999cecac0>,
#  <shapely.geometry.point.Point at 0x17999cecb20>,
#  <shapely.geometry.point.Point at 0x17999cecb80>,
#  <shapely.geometry.point.Point at 0x17999cecbe0>,
#  <shapely.geometry.point.Point at 0x17999cecc40>,
#  <shapely.geometry.point.Point at 0x17999cecca0>,
#  <shapely.geometry.point.Point at 0x17999cecd00>,
#  <shapely.geometry.point.Point at 0x17999cecd60>,
#  <shapely.geometry.point.Point at 0x17999cecdc0>,
#  <shapely.geometry.point.Point at 0x17999cece20>,
#  <shapely.geometry.point.Point at 0x17999cece80>,
#  <shapely.geometry.point.Point at 0x17999cecee0>,
#  <shapely.geometry.point.Point at 0x17999cecf40>,
#  <shapely.geometry.point.Point at 0x17999cecfa0>,
#  <shapely.geometry.point.Point at 0x17999cee040>,
#  <shapely.geometry.point.Point at 0x17999cee0a0>,
#  <shapely.geometry.point.Point at 0x17999cee100>,
#  <shapely.geometry.point.Point at 0x17999cee160>,
#  <shapely.geometry.point.Point at 0x17999cee1c0>,
#  <shapely.geometry.point.Point at 0x17999cee220>,
#  <shapely.geometry.point.Point at 0x17999cee280>,
#  <shapely.geometry.point.Point at 0x17999cee2e0>,
#  <shapely.geometry.point.Point at 0x17999cee340>,
#  <shapely.geometry.point.Point at 0x17999cee3a0>,
#  <shapely.geometry.point.Point at 0x17999cee400>,
#  <shapely.geometry.point.Point at 0x17999cee460>,
#  <shapely.geometry.point.Point at 0x17999cee4c0>,
#  <shapely.geometry.point.Point at 0x17999cee520>,
#  <shapely.geometry.point.Point at 0x17999cee580>,
#  <shapely.geometry.point.Point at 0x17999cee5e0>,
#  <shapely.geometry.point.Point at 0x17999cee640>,
#  <shapely.geometry.point.Point at 0x17999cee6a0>,
#  <shapely.geometry.point.Point at 0x17999cee700>,
#  <shapely.geometry.point.Point at 0x17999cee760>,
#  <shapely.geometry.point.Point at 0x17999cee7c0>,
#  <shapely.geometry.point.Point at 0x17999cee820>,
#  <shapely.geometry.point.Point at 0x17999cee880>,
#  <shapely.geometry.point.Point at 0x17999cee8e0>,
#  <shapely.geometry.point.Point at 0x17999cee940>,
#  <shapely.geometry.point.Point at 0x17999cee9a0>,
#  <shapely.geometry.point.Point at 0x17999ceea00>,
#  <shapely.geometry.point.Point at 0x17999ceea60>,
#  <shapely.geometry.point.Point at 0x17999ceeac0>,
#  <shapely.geometry.point.Point at 0x17999ceeb20>,
#  <shapely.geometry.point.Point at 0x17999ceeb80>,
#  <shapely.geometry.point.Point at 0x17999ceebe0>,
#  <shapely.geometry.point.Point at 0x17999ceec40>,
#  <shapely.geometry.point.Point at 0x17999ceeca0>,
#  <shapely.geometry.point.Point at 0x17999ceed00>,
#  <shapely.geometry.point.Point at 0x17999ceed60>,
#  <shapely.geometry.point.Point at 0x17999ceedc0>,
#  <shapely.geometry.point.Point at 0x17999ceee20>,
#  <shapely.geometry.point.Point at 0x17999ceee80>,
#  <shapely.geometry.point.Point at 0x17999ceeee0>,
#  <shapely.geometry.point.Point at 0x17999ceef40>,
#  <shapely.geometry.point.Point at 0x17999ceefa0>,
#  <shapely.geometry.point.Point at 0x17999cf0040>,
#  <shapely.geometry.point.Point at 0x17999cf00a0>,
#  <shapely.geometry.point.Point at 0x17999cf0100>,
#  <shapely.geometry.point.Point at 0x17999cf0160>,
#  <shapely.geometry.point.Point at 0x17999cf01c0>,
#  <shapely.geometry.point.Point at 0x17999cf0220>,
#  <shapely.geometry.point.Point at 0x17999cf0280>,
#  <shapely.geometry.point.Point at 0x17999cf02e0>,
#  <shapely.geometry.point.Point at 0x17999cf0340>,
#  <shapely.geometry.point.Point at 0x17999cf03a0>,
#  <shapely.geometry.point.Point at 0x17999cf0400>,
#  <shapely.geometry.point.Point at 0x17999cf0460>,
#  <shapely.geometry.point.Point at 0x17999cf04c0>,
#  <shapely.geometry.point.Point at 0x17999cf0520>,
#  <shapely.geometry.point.Point at 0x17999cf0580>,
#  <shapely.geometry.point.Point at 0x17999cf05e0>,
#  <shapely.geometry.point.Point at 0x17999cf0640>,
#  <shapely.geometry.point.Point at 0x17999cf06a0>,
#  <shapely.geometry.point.Point at 0x17999cf0700>,
#  <shapely.geometry.point.Point at 0x17999cf0760>,
#  <shapely.geometry.point.Point at 0x17999cf07c0>,
#  <shapely.geometry.point.Point at 0x17999cf0820>,
#  <shapely.geometry.point.Point at 0x17996e4f040>,
#  <shapely.geometry.point.Point at 0x17999cf0880>,
#  <shapely.geometry.point.Point at 0x17999cf08e0>,
#  <shapely.geometry.point.Point at 0x17999cf0940>,
#  <shapely.geometry.point.Point at 0x17999cf09a0>,
#  <shapely.geometry.point.Point at 0x17999cf0a00>,
#  <shapely.geometry.point.Point at 0x17999cf0a60>,
#  <shapely.geometry.point.Point at 0x17999cf0ac0>,
#  <shapely.geometry.point.Point at 0x17999cf0b20>,
#  <shapely.geometry.point.Point at 0x17999cf0b80>,
#  <shapely.geometry.point.Point at 0x17999cf0be0>,
#  <shapely.geometry.point.Point at 0x17999cf0c40>,
#  <shapely.geometry.point.Point at 0x17999cf0ca0>,
#  <shapely.geometry.point.Point at 0x17999cf0d00>,
#  <shapely.geometry.point.Point at 0x17999cf0d60>,
#  <shapely.geometry.point.Point at 0x17999cf0dc0>,
#  <shapely.geometry.point.Point at 0x17999cf0e20>,
#  <shapely.geometry.point.Point at 0x17999cf0e80>,
#  <shapely.geometry.point.Point at 0x17999cf0ee0>,
#  <shapely.geometry.point.Point at 0x17999cf0f40>,
#  <shapely.geometry.point.Point at 0x17999cf0fa0>,
#  <shapely.geometry.point.Point at 0x17999cf3040>,
#  <shapely.geometry.point.Point at 0x17999cf30a0>,
#  <shapely.geometry.point.Point at 0x17999cf3100>,
#  <shapely.geometry.point.Point at 0x17999cf3160>,
#  <shapely.geometry.point.Point at 0x17999cf31c0>,
#  <shapely.geometry.point.Point at 0x17999cf3220>,
#  <shapely.geometry.point.Point at 0x17999cf3280>,
#  <shapely.geometry.point.Point at 0x17999cf32e0>,
#  <shapely.geometry.point.Point at 0x17999cf3340>,
#  <shapely.geometry.point.Point at 0x17999cf33a0>,
#  <shapely.geometry.point.Point at 0x17999cf3400>,
#  <shapely.geometry.point.Point at 0x17999cf3460>,
#  <shapely.geometry.point.Point at 0x17999cf34c0>,
#  <shapely.geometry.point.Point at 0x17999cf3520>,
#  <shapely.geometry.point.Point at 0x17999cf3580>,
#  <shapely.geometry.point.Point at 0x17999cf35e0>,
#  <shapely.geometry.point.Point at 0x17999cf3640>,
#  <shapely.geometry.point.Point at 0x17999cf36a0>,
#  <shapely.geometry.point.Point at 0x17999cf3700>,
#  <shapely.geometry.point.Point at 0x17999cf3760>,
#  <shapely.geometry.point.Point at 0x17999cf37c0>,
#  <shapely.geometry.point.Point at 0x17999cf3820>,
#  <shapely.geometry.point.Point at 0x17999cf3880>,
#  <shapely.geometry.point.Point at 0x17999cf38e0>,
#  <shapely.geometry.point.Point at 0x17999cf3940>,
#  <shapely.geometry.point.Point at 0x17999cf39a0>,
#  <shapely.geometry.point.Point at 0x17999cf3a00>,
#  <shapely.geometry.point.Point at 0x17999cf3a60>,
#  <shapely.geometry.point.Point at 0x17999cf3ac0>,
#  <shapely.geometry.point.Point at 0x17999cf3b20>,
#  <shapely.geometry.point.Point at 0x17999cf3b80>,
#  <shapely.geometry.point.Point at 0x17999cf3be0>,
#  <shapely.geometry.point.Point at 0x17999cf3c40>,
#  <shapely.geometry.point.Point at 0x17999cf3ca0>,
#  <shapely.geometry.point.Point at 0x17999cf3d00>,
#  <shapely.geometry.point.Point at 0x17999cf3d60>,
#  <shapely.geometry.point.Point at 0x17999cf3dc0>,
#  <shapely.geometry.point.Point at 0x17999cf3e20>,
#  <shapely.geometry.point.Point at 0x17999cf3e80>,
#  <shapely.geometry.point.Point at 0x17999cf3ee0>,
#  <shapely.geometry.point.Point at 0x17999cf3f40>,
#  <shapely.geometry.point.Point at 0x17999cf3fa0>,
#  <shapely.geometry.point.Point at 0x17999cf5040>,
#  <shapely.geometry.point.Point at 0x17999cf50a0>,
#  <shapely.geometry.point.Point at 0x17999cf5100>,
#  <shapely.geometry.point.Point at 0x17999cf5160>,
#  <shapely.geometry.point.Point at 0x17999cf51c0>,
#  <shapely.geometry.point.Point at 0x17999cf5220>,
#  <shapely.geometry.point.Point at 0x17999cf5280>,
#  <shapely.geometry.point.Point at 0x17999cf52e0>,
#  <shapely.geometry.point.Point at 0x17999cf5340>,
#  <shapely.geometry.point.Point at 0x17999cf53a0>,
#  <shapely.geometry.point.Point at 0x17999cf5400>,
#  <shapely.geometry.point.Point at 0x17999cf5460>,
#  <shapely.geometry.point.Point at 0x17999cf54c0>,
#  <shapely.geometry.point.Point at 0x17999cf5520>,
#  <shapely.geometry.point.Point at 0x17999cf5580>,
#  <shapely.geometry.point.Point at 0x17999cf55e0>,
#  <shapely.geometry.point.Point at 0x17999cf5640>,
#  <shapely.geometry.point.Point at 0x17999cf56a0>,
#  <shapely.geometry.point.Point at 0x17999cf5700>,
#  <shapely.geometry.point.Point at 0x17999cf5760>,
#  <shapely.geometry.point.Point at 0x17999cf57c0>,
#  <shapely.geometry.point.Point at 0x17999cf5820>,
#  <shapely.geometry.point.Point at 0x17999cf5880>,
#  <shapely.geometry.point.Point at 0x17999cf58e0>,
#  <shapely.geometry.point.Point at 0x17999cf5940>,
#  <shapely.geometry.point.Point at 0x17999cf59a0>,
#  <shapely.geometry.point.Point at 0x17999cf5a00>,
#  <shapely.geometry.point.Point at 0x17999cf5a60>,
#  <shapely.geometry.point.Point at 0x17999cf5ac0>,
#  <shapely.geometry.point.Point at 0x17999cf5b20>,
#  <shapely.geometry.point.Point at 0x17999cf5b80>,
#  <shapely.geometry.point.Point at 0x17999cf5be0>,
#  <shapely.geometry.point.Point at 0x17999cf5c40>,
#  <shapely.geometry.point.Point at 0x17999cf5ca0>,
#  <shapely.geometry.point.Point at 0x17999cf5d00>,
#  <shapely.geometry.point.Point at 0x17999cf5d60>,
#  <shapely.geometry.point.Point at 0x17999cf5dc0>,
#  <shapely.geometry.point.Point at 0x17999cf5e20>,
#  <shapely.geometry.point.Point at 0x17999cf5e80>,
#  <shapely.geometry.point.Point at 0x17999cf5ee0>,
#  <shapely.geometry.point.Point at 0x17999cf5f40>,
#  <shapely.geometry.point.Point at 0x17999cf5fa0>,
#  <shapely.geometry.point.Point at 0x17999cf7040>,
#  <shapely.geometry.point.Point at 0x17999cf70a0>,
#  <shapely.geometry.point.Point at 0x17999cf7100>,
#  <shapely.geometry.point.Point at 0x17999cf7160>,
#  <shapely.geometry.point.Point at 0x17999cf71c0>,
#  <shapely.geometry.point.Point at 0x17999cf7220>,
#  <shapely.geometry.point.Point at 0x17999cf7280>,
#  <shapely.geometry.point.Point at 0x17999cf72e0>,
#  <shapely.geometry.point.Point at 0x17999cf7340>,
#  <shapely.geometry.point.Point at 0x17999cf73a0>,
#  <shapely.geometry.point.Point at 0x17999cf7400>,
#  <shapely.geometry.point.Point at 0x17999cf7460>,
#  <shapely.geometry.point.Point at 0x17999cf74c0>,
#  <shapely.geometry.point.Point at 0x17999cf7520>,
#  <shapely.geometry.point.Point at 0x17999cf7580>,
#  <shapely.geometry.point.Point at 0x17999cf75e0>,
#  <shapely.geometry.point.Point at 0x17999cf7640>,
#  <shapely.geometry.point.Point at 0x17999cf76a0>,
#  <shapely.geometry.point.Point at 0x17999cf7700>,
#  <shapely.geometry.point.Point at 0x17999cf7760>,
#  <shapely.geometry.point.Point at 0x17999cf77c0>,
#  <shapely.geometry.point.Point at 0x17999cf7820>,
#  <shapely.geometry.point.Point at 0x17999cf7880>,
#  <shapely.geometry.point.Point at 0x17999cf78e0>,
#  <shapely.geometry.point.Point at 0x17999cf7940>,
#  <shapely.geometry.point.Point at 0x17999cf79a0>,
#  <shapely.geometry.point.Point at 0x17999cf7a00>,
#  <shapely.geometry.point.Point at 0x17999cf7a60>,
#  <shapely.geometry.point.Point at 0x17999cf7ac0>,
#  <shapely.geometry.point.Point at 0x17999cf7b20>,
#  <shapely.geometry.point.Point at 0x17999cf7b80>,
#  <shapely.geometry.point.Point at 0x17999cf7be0>,
#  <shapely.geometry.point.Point at 0x17999cf7c40>,
#  <shapely.geometry.point.Point at 0x17999cf7ca0>,
#  <shapely.geometry.point.Point at 0x17999cf7d00>,
#  <shapely.geometry.point.Point at 0x17999cf7d60>,
#  <shapely.geometry.point.Point at 0x17999cf7dc0>,
#  <shapely.geometry.point.Point at 0x17999cf7e20>,
#  <shapely.geometry.point.Point at 0x17999cf7e80>,
#  <shapely.geometry.point.Point at 0x17999cf7ee0>,
#  <shapely.geometry.point.Point at 0x17999cf7f40>,
#  <shapely.geometry.point.Point at 0x17999cf7fa0>,
#  <shapely.geometry.point.Point at 0x17999cf9040>,
#  <shapely.geometry.point.Point at 0x17999cf90a0>,
#  <shapely.geometry.point.Point at 0x17999cf9100>,
#  <shapely.geometry.point.Point at 0x17999cf9160>,
#  <shapely.geometry.point.Point at 0x17999cf91c0>,
#  <shapely.geometry.point.Point at 0x17999cf9220>,
#  <shapely.geometry.point.Point at 0x17999cf9280>,
#  <shapely.geometry.point.Point at 0x17999cf92e0>,
#  <shapely.geometry.point.Point at 0x17999cf9340>,
#  <shapely.geometry.point.Point at 0x17999cf93a0>,
#  <shapely.geometry.point.Point at 0x17999cf9400>,
#  <shapely.geometry.point.Point at 0x17999cf9460>,
#  <shapely.geometry.point.Point at 0x17999cf94c0>,
#  <shapely.geometry.point.Point at 0x17999cf9520>,
#  <shapely.geometry.point.Point at 0x17999cf9580>,
#  <shapely.geometry.point.Point at 0x17999cf95e0>,
#  <shapely.geometry.point.Point at 0x17999cf9640>,
#  <shapely.geometry.point.Point at 0x17999cf96a0>,
#  <shapely.geometry.point.Point at 0x17999cf9700>,
#  <shapely.geometry.point.Point at 0x17999cf9760>,
#  <shapely.geometry.point.Point at 0x17999cf97c0>,
#  <shapely.geometry.point.Point at 0x17999cf9820>,
#  <shapely.geometry.point.Point at 0x17999cf9880>,
#  <shapely.geometry.point.Point at 0x17999cf98e0>,
#  <shapely.geometry.point.Point at 0x17999cf9940>,
#  <shapely.geometry.point.Point at 0x17999cf99a0>,
#  <shapely.geometry.point.Point at 0x17999cf9a00>,
#  <shapely.geometry.point.Point at 0x17999cf9a60>,
#  <shapely.geometry.point.Point at 0x17999cf9ac0>,
#  <shapely.geometry.point.Point at 0x17999cf9b20>,
#  <shapely.geometry.point.Point at 0x17999cf9b80>,
#  <shapely.geometry.point.Point at 0x17999cf9be0>,
#  <shapely.geometry.point.Point at 0x17999cf9c40>,
#  <shapely.geometry.point.Point at 0x17999cf9ca0>,
#  <shapely.geometry.point.Point at 0x17999cf9d00>,
#  <shapely.geometry.point.Point at 0x17999cf9d60>,
#  <shapely.geometry.point.Point at 0x17999cf9dc0>,
#  <shapely.geometry.point.Point at 0x17999cf9e20>,
#  <shapely.geometry.point.Point at 0x17999cf9e80>,
#  <shapely.geometry.point.Point at 0x17999cf9ee0>,
#  <shapely.geometry.point.Point at 0x17999cf9f40>,
#  <shapely.geometry.point.Point at 0x17999cf9fa0>,
#  <shapely.geometry.point.Point at 0x17999cfb040>,
#  <shapely.geometry.point.Point at 0x17999cfb0a0>,
#  <shapely.geometry.point.Point at 0x17999cfb100>,
#  <shapely.geometry.point.Point at 0x17999cfb160>,
#  <shapely.geometry.point.Point at 0x17999cfb1c0>,
#  <shapely.geometry.point.Point at 0x17999cfb220>,
#  <shapely.geometry.point.Point at 0x17999cfb280>,
#  <shapely.geometry.point.Point at 0x17999cfb2e0>,
#  <shapely.geometry.point.Point at 0x17999cfb340>,
#  <shapely.geometry.point.Point at 0x17999cfb3a0>,
#  <shapely.geometry.point.Point at 0x17999cfb400>,
#  <shapely.geometry.point.Point at 0x17999cfb460>,
#  <shapely.geometry.point.Point at 0x17999cfb4c0>,
#  <shapely.geometry.point.Point at 0x17999cfb520>,
#  <shapely.geometry.point.Point at 0x17999cfb580>,
#  <shapely.geometry.point.Point at 0x17999cfb5e0>,
#  <shapely.geometry.point.Point at 0x17999cfb640>,
#  <shapely.geometry.point.Point at 0x17999cfb6a0>,
#  <shapely.geometry.point.Point at 0x17999cfb700>,
#  <shapely.geometry.point.Point at 0x17999cfb760>,
#  <shapely.geometry.point.Point at 0x17999cfb7c0>,
#  <shapely.geometry.point.Point at 0x17999cfb820>,
#  <shapely.geometry.point.Point at 0x17999cfb880>,
#  <shapely.geometry.point.Point at 0x17999cfb8e0>,
#  <shapely.geometry.point.Point at 0x17999cfb940>,
#  <shapely.geometry.point.Point at 0x17999cfb9a0>,
#  <shapely.geometry.point.Point at 0x17999cfba00>,
#  <shapely.geometry.point.Point at 0x17999cfba60>,
#  <shapely.geometry.point.Point at 0x17999cfbac0>,
#  <shapely.geometry.point.Point at 0x17999cfbb20>,
#  <shapely.geometry.point.Point at 0x17999cfbb80>,
#  <shapely.geometry.point.Point at 0x17999cfbbe0>,
#  <shapely.geometry.point.Point at 0x17999cfbc40>,
#  <shapely.geometry.point.Point at 0x17999cfbca0>,
#  <shapely.geometry.point.Point at 0x17999cfbd00>,
#  <shapely.geometry.point.Point at 0x17999cfbd60>,
#  <shapely.geometry.point.Point at 0x17999cfbdc0>,
#  <shapely.geometry.point.Point at 0x17999cfbe20>,
#  <shapely.geometry.point.Point at 0x17999cfbe80>,
#  <shapely.geometry.point.Point at 0x17999cfbee0>,
#  <shapely.geometry.point.Point at 0x17999cfbf40>,
#  <shapely.geometry.point.Point at 0x17999cfbfa0>,
#  <shapely.geometry.point.Point at 0x17999cfd040>,
#  <shapely.geometry.point.Point at 0x17999cfd0a0>,
#  <shapely.geometry.point.Point at 0x17999cfd100>,
#  <shapely.geometry.point.Point at 0x17999cfd160>,
#  <shapely.geometry.point.Point at 0x17999cfd1c0>,
#  <shapely.geometry.point.Point at 0x17999cfd220>,
#  <shapely.geometry.point.Point at 0x17999cfd280>,
#  <shapely.geometry.point.Point at 0x17999cfd2e0>,
#  <shapely.geometry.point.Point at 0x17999cfd340>,
#  <shapely.geometry.point.Point at 0x17999cfd3a0>,
#  <shapely.geometry.point.Point at 0x17999cfd400>,
#  <shapely.geometry.point.Point at 0x17999cfd460>,
#  <shapely.geometry.point.Point at 0x17999cfd4c0>,
#  <shapely.geometry.point.Point at 0x17999cfd520>,
#  <shapely.geometry.point.Point at 0x17999cfd580>,
#  <shapely.geometry.point.Point at 0x17999cfd5e0>,
#  <shapely.geometry.point.Point at 0x17999cfd640>,
#  <shapely.geometry.point.Point at 0x17999cfd6a0>,
#  <shapely.geometry.point.Point at 0x17999cfd700>,
#  <shapely.geometry.point.Point at 0x17999cfd760>,
#  <shapely.geometry.point.Point at 0x17999cfd7c0>,
#  <shapely.geometry.point.Point at 0x17999cfd820>,
#  <shapely.geometry.point.Point at 0x17999cfd880>,
#  <shapely.geometry.point.Point at 0x17999cfd8e0>,
#  <shapely.geometry.point.Point at 0x17999cfd940>,
#  <shapely.geometry.point.Point at 0x17999cfd9a0>,
#  <shapely.geometry.point.Point at 0x17999cfda00>,
#  <shapely.geometry.point.Point at 0x17999cfda60>,
#  <shapely.geometry.point.Point at 0x17999cfdac0>,
#  <shapely.geometry.point.Point at 0x17999cfdb20>,
#  <shapely.geometry.point.Point at 0x17999cfdb80>,
#  <shapely.geometry.point.Point at 0x17999cfdbe0>,
#  <shapely.geometry.point.Point at 0x17999cfdc40>,
#  <shapely.geometry.point.Point at 0x17999cfdca0>,
#  <shapely.geometry.point.Point at 0x17999cfdd00>,
#  <shapely.geometry.point.Point at 0x17999cfdd60>,
#  <shapely.geometry.point.Point at 0x17999cfddc0>,
#  <shapely.geometry.point.Point at 0x17999cfde20>,
#  <shapely.geometry.point.Point at 0x17999cfde80>,
#  <shapely.geometry.point.Point at 0x17999cfdee0>,
#  <shapely.geometry.point.Point at 0x17999cfdf40>,
#  <shapely.geometry.point.Point at 0x17999cfdfa0>,
#  <shapely.geometry.point.Point at 0x17999cff040>,
#  <shapely.geometry.point.Point at 0x17999cff0a0>,
#  <shapely.geometry.point.Point at 0x17999cff100>,
#  <shapely.geometry.point.Point at 0x17999cff160>,
#  <shapely.geometry.point.Point at 0x17999cff1c0>,
#  <shapely.geometry.point.Point at 0x17999cff220>,
#  <shapely.geometry.point.Point at 0x17999cff280>,
#  <shapely.geometry.point.Point at 0x17999cff2e0>,
#  <shapely.geometry.point.Point at 0x17999cff340>,
#  <shapely.geometry.point.Point at 0x17999cff3a0>,
#  <shapely.geometry.point.Point at 0x17999cff400>,
#  <shapely.geometry.point.Point at 0x17999cff460>,
#  <shapely.geometry.point.Point at 0x17999cff4c0>,
#  <shapely.geometry.point.Point at 0x17999cff520>,
#  <shapely.geometry.point.Point at 0x17999cff580>,
#  <shapely.geometry.point.Point at 0x17999cff5e0>,
#  <shapely.geometry.point.Point at 0x17999cff640>,
#  <shapely.geometry.point.Point at 0x17999cff6a0>,
#  <shapely.geometry.point.Point at 0x17999cff700>,
#  <shapely.geometry.point.Point at 0x17999cff760>,
#  <shapely.geometry.point.Point at 0x17999cff7c0>,
#  <shapely.geometry.point.Point at 0x17999cff820>,
#  <shapely.geometry.point.Point at 0x17999cff880>,
#  <shapely.geometry.point.Point at 0x17999cff8e0>,
#  <shapely.geometry.point.Point at 0x17999cff940>,
#  <shapely.geometry.point.Point at 0x17999cff9a0>,
#  <shapely.geometry.point.Point at 0x17999cffa00>,
#  <shapely.geometry.point.Point at 0x17999cffa60>,
#  <shapely.geometry.point.Point at 0x17999cffac0>,
#  <shapely.geometry.point.Point at 0x17999cffb20>,
#  <shapely.geometry.point.Point at 0x17999cffb80>,
#  <shapely.geometry.point.Point at 0x17999cffbe0>,
#  <shapely.geometry.point.Point at 0x17999cffc40>,
#  <shapely.geometry.point.Point at 0x17999cffca0>,
#  <shapely.geometry.point.Point at 0x17999cffd00>,
#  <shapely.geometry.point.Point at 0x17999cffd60>,
#  <shapely.geometry.point.Point at 0x17999cffdc0>,
#  <shapely.geometry.point.Point at 0x17999cffe20>,
#  <shapely.geometry.point.Point at 0x17999cffe80>,
#  <shapely.geometry.point.Point at 0x17999cffee0>,
#  <shapely.geometry.point.Point at 0x17999cfff40>,
#  <shapely.geometry.point.Point at 0x17999cfffa0>,
#  <shapely.geometry.point.Point at 0x17999d01040>,
#  <shapely.geometry.point.Point at 0x17999d010a0>,
#  <shapely.geometry.point.Point at 0x17999d01100>,
#  <shapely.geometry.point.Point at 0x17999d01160>,
#  <shapely.geometry.point.Point at 0x17999d011c0>,
#  <shapely.geometry.point.Point at 0x17999d01220>,
#  <shapely.geometry.point.Point at 0x17999d01280>,
#  <shapely.geometry.point.Point at 0x17999d012e0>,
#  <shapely.geometry.point.Point at 0x17999d01340>,
#  <shapely.geometry.point.Point at 0x17999d013a0>,
#  <shapely.geometry.point.Point at 0x17999d01400>,
#  <shapely.geometry.point.Point at 0x17999d01460>,
#  <shapely.geometry.point.Point at 0x17999d014c0>,
#  <shapely.geometry.point.Point at 0x17999d01520>,
#  <shapely.geometry.point.Point at 0x17999d01580>,
#  <shapely.geometry.point.Point at 0x17999d015e0>,
#  <shapely.geometry.point.Point at 0x17999d01640>,
#  <shapely.geometry.point.Point at 0x17999d016a0>,
#  <shapely.geometry.point.Point at 0x17999d01700>,
#  <shapely.geometry.point.Point at 0x17999d01760>,
#  <shapely.geometry.point.Point at 0x17999d017c0>,
#  <shapely.geometry.point.Point at 0x17999d01820>,
#  <shapely.geometry.point.Point at 0x17999d01880>,
#  <shapely.geometry.point.Point at 0x17999d018e0>,
#  <shapely.geometry.point.Point at 0x17999d01940>,
#  <shapely.geometry.point.Point at 0x17999d019a0>,
#  <shapely.geometry.point.Point at 0x17999d01a00>,
#  <shapely.geometry.point.Point at 0x17999d01a60>,
#  <shapely.geometry.point.Point at 0x17999d01ac0>,
#  <shapely.geometry.point.Point at 0x17999d01b20>,
#  <shapely.geometry.point.Point at 0x17999d01b80>,
#  <shapely.geometry.point.Point at 0x17999d01be0>,
#  <shapely.geometry.point.Point at 0x17999d01c40>,
#  <shapely.geometry.point.Point at 0x17999d01ca0>,
#  <shapely.geometry.point.Point at 0x17999d01d00>,
#  <shapely.geometry.point.Point at 0x17999d01d60>,
#  <shapely.geometry.point.Point at 0x17999d01dc0>,
#  <shapely.geometry.point.Point at 0x17999d01e20>,
#  <shapely.geometry.point.Point at 0x17999d01e80>,
#  <shapely.geometry.point.Point at 0x17999d01ee0>,
#  <shapely.geometry.point.Point at 0x17999d01f40>,
#  <shapely.geometry.point.Point at 0x17999d01fa0>,
#  <shapely.geometry.point.Point at 0x17999d03040>,
#  <shapely.geometry.point.Point at 0x17999d030a0>,
#  <shapely.geometry.point.Point at 0x17999d03100>,
#  <shapely.geometry.point.Point at 0x17999d03160>,
#  <shapely.geometry.point.Point at 0x17999d031c0>,
#  <shapely.geometry.point.Point at 0x17999d03220>,
#  <shapely.geometry.point.Point at 0x17999d03280>,
#  <shapely.geometry.point.Point at 0x17999d032e0>,
#  <shapely.geometry.point.Point at 0x17999d03340>,
#  <shapely.geometry.point.Point at 0x17999d033a0>,
#  <shapely.geometry.point.Point at 0x17999d03400>,
#  <shapely.geometry.point.Point at 0x17999d03460>,
#  <shapely.geometry.point.Point at 0x17999d034c0>,
#  <shapely.geometry.point.Point at 0x17999d03520>,
#  <shapely.geometry.point.Point at 0x17999d03580>,
#  <shapely.geometry.point.Point at 0x17999d035e0>,
#  <shapely.geometry.point.Point at 0x17999d03640>,
#  <shapely.geometry.point.Point at 0x17999d036a0>,
#  <shapely.geometry.point.Point at 0x17999d03700>,
#  <shapely.geometry.point.Point at 0x17999d03760>,
#  <shapely.geometry.point.Point at 0x17999d037c0>,
#  <shapely.geometry.point.Point at 0x17999d03820>,
#  <shapely.geometry.point.Point at 0x17999d03880>,
#  <shapely.geometry.point.Point at 0x17999d038e0>,
#  <shapely.geometry.point.Point at 0x17999d03940>,
#  <shapely.geometry.point.Point at 0x17999d039a0>,
#  <shapely.geometry.point.Point at 0x17999d03a00>,
#  <shapely.geometry.point.Point at 0x17999d03a60>,
#  <shapely.geometry.point.Point at 0x17999d03ac0>,
#  <shapely.geometry.point.Point at 0x17999d03b20>,
#  <shapely.geometry.point.Point at 0x17999d03b80>,
#  <shapely.geometry.point.Point at 0x17999d03be0>,
#  <shapely.geometry.point.Point at 0x17999d03c40>,
#  <shapely.geometry.point.Point at 0x17999d03ca0>,
#  <shapely.geometry.point.Point at 0x17999d03d00>,
#  <shapely.geometry.point.Point at 0x17999d03d60>,
#  <shapely.geometry.point.Point at 0x17999d03dc0>,
#  <shapely.geometry.point.Point at 0x17999d03e20>,
#  <shapely.geometry.point.Point at 0x17999d03e80>,
#  <shapely.geometry.point.Point at 0x17999d03ee0>,
#  <shapely.geometry.point.Point at 0x17999d03f40>,
#  <shapely.geometry.point.Point at 0x17999d03fa0>,
#  <shapely.geometry.point.Point at 0x17999d05040>,
#  <shapely.geometry.point.Point at 0x17999d050a0>,
#  <shapely.geometry.point.Point at 0x17999d05100>,
#  <shapely.geometry.point.Point at 0x17999d05160>,
#  <shapely.geometry.point.Point at 0x17999d051c0>,
#  <shapely.geometry.point.Point at 0x17999d05220>,
#  <shapely.geometry.point.Point at 0x17999d05280>,
#  <shapely.geometry.point.Point at 0x17999d052e0>,
#  <shapely.geometry.point.Point at 0x17999d05340>,
#  <shapely.geometry.point.Point at 0x17999d053a0>,
#  <shapely.geometry.point.Point at 0x17999d05400>,
#  <shapely.geometry.point.Point at 0x17999d05460>,
#  <shapely.geometry.point.Point at 0x17999d054c0>,
#  <shapely.geometry.point.Point at 0x17999d05520>,
#  <shapely.geometry.point.Point at 0x17999d05580>,
#  <shapely.geometry.point.Point at 0x17999d055e0>,
#  <shapely.geometry.point.Point at 0x17999d05640>,
#  <shapely.geometry.point.Point at 0x17999d056a0>,
#  <shapely.geometry.point.Point at 0x17999d05700>,
#  <shapely.geometry.point.Point at 0x17999d05760>,
#  <shapely.geometry.point.Point at 0x17999d057c0>,
#  <shapely.geometry.point.Point at 0x17999d05820>,
#  <shapely.geometry.point.Point at 0x17999d05880>,
#  <shapely.geometry.point.Point at 0x17999d058e0>,
#  <shapely.geometry.point.Point at 0x17999d05940>,
#  <shapely.geometry.point.Point at 0x17999d059a0>,
#  <shapely.geometry.point.Point at 0x17999d05a00>,
#  <shapely.geometry.point.Point at 0x17999d05a60>,
#  <shapely.geometry.point.Point at 0x17999d05ac0>,
#  <shapely.geometry.point.Point at 0x17999d05b20>,
#  <shapely.geometry.point.Point at 0x17999d05b80>,
#  <shapely.geometry.point.Point at 0x17999d05be0>,
#  <shapely.geometry.point.Point at 0x17999d05c40>,
#  <shapely.geometry.point.Point at 0x17999d05ca0>,
#  <shapely.geometry.point.Point at 0x17999d05d00>,
#  <shapely.geometry.point.Point at 0x17999d05d60>,
#  <shapely.geometry.point.Point at 0x17999d05dc0>,
#  <shapely.geometry.point.Point at 0x17999d05e20>,
#  <shapely.geometry.point.Point at 0x17999d05e80>,
#  <shapely.geometry.point.Point at 0x17999d05ee0>,
#  <shapely.geometry.point.Point at 0x17999d05f40>,
#  <shapely.geometry.point.Point at 0x17999d05fa0>,
#  <shapely.geometry.point.Point at 0x17999d07040>,
#  <shapely.geometry.point.Point at 0x17999d070a0>,
#  <shapely.geometry.point.Point at 0x17999d07100>,
#  <shapely.geometry.point.Point at 0x17999d07160>,
#  <shapely.geometry.point.Point at 0x17999d071c0>,
#  <shapely.geometry.point.Point at 0x17999d07220>,
#  <shapely.geometry.point.Point at 0x17999d07280>,
#  <shapely.geometry.point.Point at 0x17999d072e0>,
#  <shapely.geometry.point.Point at 0x17999d07340>,
#  <shapely.geometry.point.Point at 0x17999d073a0>,
#  <shapely.geometry.point.Point at 0x17999d07400>,
#  <shapely.geometry.point.Point at 0x17999d07460>,
#  <shapely.geometry.point.Point at 0x17999d074c0>,
#  <shapely.geometry.point.Point at 0x17999d07520>,
#  <shapely.geometry.point.Point at 0x17999d07580>,
#  <shapely.geometry.point.Point at 0x17999d075e0>,
#  <shapely.geometry.point.Point at 0x17999d07640>,
#  <shapely.geometry.point.Point at 0x17999d076a0>,
#  <shapely.geometry.point.Point at 0x17999d07700>,
#  <shapely.geometry.point.Point at 0x17999d07760>,
#  <shapely.geometry.point.Point at 0x17999d077c0>,
#  <shapely.geometry.point.Point at 0x17999d07850>,
#  <shapely.geometry.point.Point at 0x17999d078b0>,
#  <shapely.geometry.point.Point at 0x17999d07910>,
#  <shapely.geometry.point.Point at 0x17999d07970>,
#  <shapely.geometry.point.Point at 0x17999d079d0>,
#  <shapely.geometry.point.Point at 0x17999d07a30>,
#  <shapely.geometry.point.Point at 0x17999d07a90>,
#  <shapely.geometry.point.Point at 0x17999d07af0>,
#  <shapely.geometry.point.Point at 0x17999d07b50>,
#  <shapely.geometry.point.Point at 0x17999d07bb0>,
#  <shapely.geometry.point.Point at 0x17999d07c10>,
#  <shapely.geometry.point.Point at 0x17999d07c70>,
#  <shapely.geometry.point.Point at 0x17999d07cd0>,
#  <shapely.geometry.point.Point at 0x17999d07d30>,
#  <shapely.geometry.point.Point at 0x17999d07d90>,
#  <shapely.geometry.point.Point at 0x17999d07df0>,
#  <shapely.geometry.point.Point at 0x17999d07e50>,
#  <shapely.geometry.point.Point at 0x17999d07eb0>,
#  <shapely.geometry.point.Point at 0x17999d07f10>,
#  <shapely.geometry.point.Point at 0x17999d07f70>,
#  <shapely.geometry.point.Point at 0x17999d07fd0>,
#  <shapely.geometry.point.Point at 0x17999d09070>,
#  <shapely.geometry.point.Point at 0x17999d090d0>,
#  <shapely.geometry.point.Point at 0x17999d09130>,
#  <shapely.geometry.point.Point at 0x17999d09190>,
#  <shapely.geometry.point.Point at 0x17999d091f0>,
#  <shapely.geometry.point.Point at 0x17999d09250>,
#  <shapely.geometry.point.Point at 0x17999d092b0>,
#  <shapely.geometry.point.Point at 0x17999d09310>,
#  <shapely.geometry.point.Point at 0x17999d09370>,
#  <shapely.geometry.point.Point at 0x17999d093d0>,
#  <shapely.geometry.point.Point at 0x17999d09430>,
#  <shapely.geometry.point.Point at 0x17999d09490>,
#  <shapely.geometry.point.Point at 0x17999d094f0>,
#  <shapely.geometry.point.Point at 0x17999d09550>,
#  <shapely.geometry.point.Point at 0x17999d095b0>,
#  <shapely.geometry.point.Point at 0x17999d09610>,
#  <shapely.geometry.point.Point at 0x17999d09670>,
#  <shapely.geometry.point.Point at 0x17999d096d0>,
#  <shapely.geometry.point.Point at 0x17999d09730>,
#  <shapely.geometry.point.Point at 0x17999d09790>,
#  <shapely.geometry.point.Point at 0x17999d097f0>,
#  <shapely.geometry.point.Point at 0x17999d09850>,
#  <shapely.geometry.point.Point at 0x17999d098b0>,
#  <shapely.geometry.point.Point at 0x17999d09910>,
#  <shapely.geometry.point.Point at 0x17999d09970>,
#  <shapely.geometry.point.Point at 0x17999d099d0>,
#  <shapely.geometry.point.Point at 0x17999d09a30>,
#  <shapely.geometry.point.Point at 0x17999d09a90>,
#  <shapely.geometry.point.Point at 0x17999d09af0>,
#  <shapely.geometry.point.Point at 0x17999d09b50>,
#  <shapely.geometry.point.Point at 0x17999d09bb0>,
#  <shapely.geometry.point.Point at 0x17999d09c10>,
#  <shapely.geometry.point.Point at 0x17999d09c70>,
#  <shapely.geometry.point.Point at 0x17999d09cd0>,
#  <shapely.geometry.point.Point at 0x17999d09d30>,
#  <shapely.geometry.point.Point at 0x17999d09d90>,
#  <shapely.geometry.point.Point at 0x17999d09df0>,
#  <shapely.geometry.point.Point at 0x17999d09e50>,
#  <shapely.geometry.point.Point at 0x17999d09eb0>,
#  <shapely.geometry.point.Point at 0x17999d09f10>,
#  <shapely.geometry.point.Point at 0x17999d09f70>,
#  <shapely.geometry.point.Point at 0x17999d09fd0>,
#  <shapely.geometry.point.Point at 0x17999d0b070>,
#  <shapely.geometry.point.Point at 0x17999d0b0d0>,
#  <shapely.geometry.point.Point at 0x17999d0b130>,
#  <shapely.geometry.point.Point at 0x17999d0b190>,
#  <shapely.geometry.point.Point at 0x17999d0b1f0>,
#  <shapely.geometry.point.Point at 0x17999d0b250>,
#  <shapely.geometry.point.Point at 0x17999d0b2b0>,
#  <shapely.geometry.point.Point at 0x17999d0b310>,
#  <shapely.geometry.point.Point at 0x17999d0b370>,
#  <shapely.geometry.point.Point at 0x17999d0b3d0>,
#  <shapely.geometry.point.Point at 0x17999d0b430>,
#  <shapely.geometry.point.Point at 0x17999d0b490>,
#  <shapely.geometry.point.Point at 0x17999d0b4f0>,
#  <shapely.geometry.point.Point at 0x17999d0b550>,
#  <shapely.geometry.point.Point at 0x17999d0b5b0>,
#  <shapely.geometry.point.Point at 0x17999d0b610>,
#  <shapely.geometry.point.Point at 0x17999d0b670>,
#  <shapely.geometry.point.Point at 0x17999d0b6d0>,
#  <shapely.geometry.point.Point at 0x17999d0b730>,
#  <shapely.geometry.point.Point at 0x17999d0b790>,
#  <shapely.geometry.point.Point at 0x17999d0b7f0>,
#  <shapely.geometry.point.Point at 0x17999d0b850>,
#  <shapely.geometry.point.Point at 0x17999d0b8b0>,
#  <shapely.geometry.point.Point at 0x17999d0b910>,
#  <shapely.geometry.point.Point at 0x17999d0b970>,
#  <shapely.geometry.point.Point at 0x17999d0b9d0>,
#  <shapely.geometry.point.Point at 0x17999d0ba30>,
#  <shapely.geometry.point.Point at 0x17999d0ba90>,
#  <shapely.geometry.point.Point at 0x17999d0baf0>,
#  <shapely.geometry.point.Point at 0x17999d0bb50>,
#  <shapely.geometry.point.Point at 0x17999d0bbb0>,
#  <shapely.geometry.point.Point at 0x17999d0bc10>,
#  <shapely.geometry.point.Point at 0x17999d0bc70>,
#  <shapely.geometry.point.Point at 0x17999d0bcd0>,
#  <shapely.geometry.point.Point at 0x17999d0bd30>,
#  <shapely.geometry.point.Point at 0x17999d0bd90>,
#  <shapely.geometry.point.Point at 0x17999d0bdf0>,
#  <shapely.geometry.point.Point at 0x17999d0be50>,
#  <shapely.geometry.point.Point at 0x17999d0beb0>,
#  <shapely.geometry.point.Point at 0x17999d0bf10>,
#  <shapely.geometry.point.Point at 0x17999d0bf70>,
#  <shapely.geometry.point.Point at 0x17999d0bfd0>,
#  <shapely.geometry.point.Point at 0x17999d0d070>,
#  <shapely.geometry.point.Point at 0x17999d0d0d0>,
#  <shapely.geometry.point.Point at 0x17999d0d130>,
#  <shapely.geometry.point.Point at 0x17999d0d190>,
#  <shapely.geometry.point.Point at 0x17999d0d1f0>,
#  <shapely.geometry.point.Point at 0x17999d0d250>,
#  <shapely.geometry.point.Point at 0x17999d0d2b0>,
#  <shapely.geometry.point.Point at 0x17999d0d310>,
#  <shapely.geometry.point.Point at 0x17999d0d370>,
#  <shapely.geometry.point.Point at 0x17999d0d3d0>,
#  <shapely.geometry.point.Point at 0x17999d0d430>,
#  <shapely.geometry.point.Point at 0x17999d0d490>,
#  <shapely.geometry.point.Point at 0x17999d0d4f0>,
#  <shapely.geometry.point.Point at 0x17999d0d550>,
#  <shapely.geometry.point.Point at 0x17999d0d5b0>,
#  <shapely.geometry.point.Point at 0x17999d0d610>,
#  <shapely.geometry.point.Point at 0x17999d0d670>,
#  <shapely.geometry.point.Point at 0x17999d0d6d0>,
#  <shapely.geometry.point.Point at 0x17999d0d730>,
#  <shapely.geometry.point.Point at 0x17999d0d790>,
#  <shapely.geometry.point.Point at 0x17999d0d7f0>,
#  <shapely.geometry.point.Point at 0x17999d0d850>,
#  <shapely.geometry.point.Point at 0x17999d0d8b0>,
#  <shapely.geometry.point.Point at 0x17999d0d910>,
#  <shapely.geometry.point.Point at 0x17999d0d970>,
#  <shapely.geometry.point.Point at 0x17999d0d9d0>,
#  <shapely.geometry.point.Point at 0x17999d0da30>,
#  <shapely.geometry.point.Point at 0x17999d0da90>,
#  <shapely.geometry.point.Point at 0x17999d0daf0>,
#  <shapely.geometry.point.Point at 0x17999d0db50>,
#  <shapely.geometry.point.Point at 0x17999d0dbb0>,
#  <shapely.geometry.point.Point at 0x17999d0dc10>,
#  <shapely.geometry.point.Point at 0x17999d0dc70>,
#  <shapely.geometry.point.Point at 0x17999d0dcd0>,
#  <shapely.geometry.point.Point at 0x17999d0dd30>,
#  <shapely.geometry.point.Point at 0x17999d0dd90>,
#  <shapely.geometry.point.Point at 0x17999d0ddf0>,
#  <shapely.geometry.point.Point at 0x17999d0de50>,
#  <shapely.geometry.point.Point at 0x17999d0deb0>,
#  <shapely.geometry.point.Point at 0x17999d0df10>,
#  <shapely.geometry.point.Point at 0x17999d0df70>,
#  <shapely.geometry.point.Point at 0x17999d0dfd0>,
#  <shapely.geometry.point.Point at 0x17999d0f070>,
#  <shapely.geometry.point.Point at 0x17999d0f0d0>,
#  <shapely.geometry.point.Point at 0x17999d0f130>,
#  <shapely.geometry.point.Point at 0x17999d0f190>,
#  <shapely.geometry.point.Point at 0x17999d0f1f0>,
#  <shapely.geometry.point.Point at 0x17999d0f250>,
#  <shapely.geometry.point.Point at 0x17999d0f2b0>,
#  <shapely.geometry.point.Point at 0x17999d0f310>,
#  <shapely.geometry.point.Point at 0x17999d0f370>,
#  <shapely.geometry.point.Point at 0x17999d0f3d0>,
#  <shapely.geometry.point.Point at 0x17999d0f430>,
#  <shapely.geometry.point.Point at 0x17999d0f490>,
#  <shapely.geometry.point.Point at 0x17999d0f4f0>,
#  <shapely.geometry.point.Point at 0x17999d0f550>,
#  <shapely.geometry.point.Point at 0x17999d0f5b0>,
#  <shapely.geometry.point.Point at 0x17999d0f610>,
#  <shapely.geometry.point.Point at 0x17999d0f670>,
#  <shapely.geometry.point.Point at 0x17999d0f6d0>,
#  <shapely.geometry.point.Point at 0x17999d0f730>,
#  <shapely.geometry.point.Point at 0x17999d0f790>,
#  <shapely.geometry.point.Point at 0x17999d0f7f0>,
#  <shapely.geometry.point.Point at 0x17999d0f850>,
#  <shapely.geometry.point.Point at 0x17999d0f8b0>,
#  <shapely.geometry.point.Point at 0x17999d0f910>,
#  <shapely.geometry.point.Point at 0x17999d0f970>,
#  <shapely.geometry.point.Point at 0x17999d0f9d0>,
#  <shapely.geometry.point.Point at 0x17999d0fa30>,
#  <shapely.geometry.point.Point at 0x17999d0fa90>,
#  <shapely.geometry.point.Point at 0x17999d0faf0>,
#  <shapely.geometry.point.Point at 0x17999d0fb50>,
#  <shapely.geometry.point.Point at 0x17999d0fbb0>,
#  <shapely.geometry.point.Point at 0x17999d0fc10>,
#  <shapely.geometry.point.Point at 0x17999d0fc70>,
#  <shapely.geometry.point.Point at 0x17999d0fcd0>,
#  <shapely.geometry.point.Point at 0x17999d0fd30>,
#  <shapely.geometry.point.Point at 0x17999d0fd90>,
#  <shapely.geometry.point.Point at 0x17999d0fdf0>,
#  <shapely.geometry.point.Point at 0x17999d0fe50>,
#  <shapely.geometry.point.Point at 0x17999d0feb0>,
#  <shapely.geometry.point.Point at 0x17999d0ff10>,
#  <shapely.geometry.point.Point at 0x17999d0ff70>,
#  <shapely.geometry.point.Point at 0x17999d0ffd0>,
#  <shapely.geometry.point.Point at 0x17999d11070>,
#  <shapely.geometry.point.Point at 0x17999d110d0>,
#  <shapely.geometry.point.Point at 0x17999d11130>,
#  <shapely.geometry.point.Point at 0x17999d11190>,
#  <shapely.geometry.point.Point at 0x17999d111f0>,
#  <shapely.geometry.point.Point at 0x17999d11250>,
#  <shapely.geometry.point.Point at 0x17999d112b0>,
#  <shapely.geometry.point.Point at 0x17999d11310>,
#  <shapely.geometry.point.Point at 0x17999d11370>,
#  <shapely.geometry.point.Point at 0x17999d113d0>,
#  <shapely.geometry.point.Point at 0x17999d11430>,
#  <shapely.geometry.point.Point at 0x17999d11490>,
#  <shapely.geometry.point.Point at 0x17999d114f0>,
#  <shapely.geometry.point.Point at 0x17999d11550>,
#  <shapely.geometry.point.Point at 0x17999d115b0>,
#  <shapely.geometry.point.Point at 0x17999d11610>,
#  <shapely.geometry.point.Point at 0x17999d11670>,
#  <shapely.geometry.point.Point at 0x17999d116d0>,
#  <shapely.geometry.point.Point at 0x17999d11730>,
#  <shapely.geometry.point.Point at 0x17999d11790>,
#  <shapely.geometry.point.Point at 0x17999d117f0>,
#  <shapely.geometry.point.Point at 0x17999d11850>,
#  <shapely.geometry.point.Point at 0x17999d118b0>,
#  <shapely.geometry.point.Point at 0x17999d11910>,
#  <shapely.geometry.point.Point at 0x17999d11970>,
#  <shapely.geometry.point.Point at 0x17999d119d0>,
#  <shapely.geometry.point.Point at 0x17999d11a30>,
#  <shapely.geometry.point.Point at 0x17999d11a90>,
#  <shapely.geometry.point.Point at 0x17999d11af0>,
#  <shapely.geometry.point.Point at 0x17999d11b50>,
#  <shapely.geometry.point.Point at 0x17999d11bb0>,
#  <shapely.geometry.point.Point at 0x17999d11c10>,
#  <shapely.geometry.point.Point at 0x17999d11c70>,
#  <shapely.geometry.point.Point at 0x17999d11cd0>,
#  <shapely.geometry.point.Point at 0x17999d11d30>,
#  <shapely.geometry.point.Point at 0x17999d11d90>,
#  <shapely.geometry.point.Point at 0x17999d11df0>,
#  <shapely.geometry.point.Point at 0x17999d11e50>,
#  <shapely.geometry.point.Point at 0x17999d11eb0>,
#  <shapely.geometry.point.Point at 0x17999d11f10>,
#  <shapely.geometry.point.Point at 0x17999d11f70>,
#  <shapely.geometry.point.Point at 0x17999d11fd0>,
#  <shapely.geometry.point.Point at 0x17999d13070>,
#  <shapely.geometry.point.Point at 0x17999d130d0>,
#  <shapely.geometry.point.Point at 0x17999d13130>,
#  <shapely.geometry.point.Point at 0x17999d13190>,
#  <shapely.geometry.point.Point at 0x17999d131f0>,
#  <shapely.geometry.point.Point at 0x17999d13250>,
#  <shapely.geometry.point.Point at 0x17999d132b0>,
#  <shapely.geometry.point.Point at 0x17999d13310>,
#  <shapely.geometry.point.Point at 0x17999d13370>,
#  <shapely.geometry.point.Point at 0x17999d133d0>,
#  <shapely.geometry.point.Point at 0x17999d13430>,
#  <shapely.geometry.point.Point at 0x17999d13490>,
#  <shapely.geometry.point.Point at 0x17999d134f0>,
#  <shapely.geometry.point.Point at 0x17999d13550>,
#  <shapely.geometry.point.Point at 0x17999d135b0>,
#  <shapely.geometry.point.Point at 0x17999d13610>,
#  <shapely.geometry.point.Point at 0x17999d13670>,
#  <shapely.geometry.point.Point at 0x17999d136d0>,
#  <shapely.geometry.point.Point at 0x17999d13730>,
#  <shapely.geometry.point.Point at 0x17999d13790>,
#  <shapely.geometry.point.Point at 0x17999d137f0>,
#  <shapely.geometry.point.Point at 0x17999d13850>,
#  <shapely.geometry.point.Point at 0x17999d138b0>,
#  <shapely.geometry.point.Point at 0x17999d13910>,
#  <shapely.geometry.point.Point at 0x17999d13970>,
#  <shapely.geometry.point.Point at 0x17999d139d0>,
#  <shapely.geometry.point.Point at 0x17999d13a30>,
#  <shapely.geometry.point.Point at 0x17999d13a90>,
#  <shapely.geometry.point.Point at 0x17999d13af0>,
#  <shapely.geometry.point.Point at 0x17999d13b50>,
#  <shapely.geometry.point.Point at 0x17999d13bb0>,
#  <shapely.geometry.point.Point at 0x17999d13c10>,
#  ...]

# %%
#configurando crs
crs = {'proj': 'latlong', 'ellps': 'WGS84', 'datum': 'WGS84', 'no_defs': True}
# atribuindo dados geometricos a uma nova coluna do df e transformando em um GEODATAFRAME
geo_dados = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
geo_dados.head()
# Out:
#   DATAOCORRENCIA PERIDOOCORRENCIA                       LOGRADOURO  NUMERO  \
# 0     31/12/2020          A NOITE  RUA PROCÓPIO BARBOSA DE MIRANDA     128
# 1     31/12/2020          A NOITE    RUA DOUTOR JOSE PEREIRA GOMES    1627
# 2     31/12/2020          A NOITE         AVENIDA GABRIELA MISTRAL      95
# 3     31/12/2020          A NOITE                   RODOVIA SP 324     520
# 4     31/12/2020          A NOITE                 RUA DOCE VITORIA       5
#
#             CIDADE  UF   LATITUDE  LONGITUDE PLACA_VEICULO DESCR_COR_VEICULO  \
# 0  ITAQUAQUECETUBA  SP -23.464688 -46.316572       DRW2B37             Verde
# 1        SÃO PAULO  SP -23.496574 -46.372711       EZP9F19             Cinza
# 2        SÃO PAULO  SP -23.516960 -46.549701       DRL4572            Branco
# 3         CAMPINAS  SP -23.024741 -47.125820       QMU9905             Prata
# 4        SÃO PAULO  SP -23.567778 -46.418146       FAY7731             Prata
#
#        DESCR_MARCA_VEICULO     ANO_MODELO DESCR_TIPO_VEICULO  \
# 0          YAMAHA/YBR 125K  NÃO INFORMADO          MOTOCICLO
# 1      FORD/KA SE 1.0 HA C  NÃO INFORMADO          AUTOMOVEL
# 2    RENAULT/KWID ZEN 10MT         2020.0          AUTOMOVEL
# 3          RENAULT/SANDERO  NÃO INFORMADO          AUTOMOVEL
# 4  CHEVROLET/ONIX 1.4MT LT         2015.0          AUTOMOVEL
#
#                       geometry
# 0  POINT (-23.46469 -46.31657)
# 1  POINT (-23.49657 -46.37271)
# 2  POINT (-23.51696 -46.54970)
# 3  POINT (-23.02474 -47.12582)
# 4  POINT (-23.56778 -46.41815)

# %%
# Definindo localização inicial do mapa
y = uf_sp.centroid.y.iloc[0]
x = uf_sp.centroid.x.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7008/2687542583.py in <module>
#       1 # Definindo localização inicial do mapa
# ----> 2 y = uf_sp.centroid.y.iloc[0]
#       3 x = uf_sp.centroid.x.iloc[0]
#
# AttributeError: 'Reader' object has no attribute 'centroid'

# %%
#setando configurações iniciais do mapa
mapa = folium.Map(location=[y,x], 
                  zoom_start=7, 
                  tiles='OpenStreetMap', alpha=0)

#adicionando contorno do estado de SP
mapa.choropleth(uf_sp[uf_sp['NM_ESTADO'] == "SÃO PAULO"],
                name='São Paulo',
                line_color='black',
                line_weight=1,
                fill_opacity=0)

#atibuindo nome do marcador
cluster = MarkerCluster(name='Carros Roubados')

#atribuindo os dados de roubos, icone e outras configurações do mapa
for item in geo_dados.itertuples():
    cluster.add_child(
        folium.Marker(location=[item.LATITUDE, item.LONGITUDE],
                      popup="TIPO: "+ str(item.DESCR_TIPO_VEICULO)+"<p>MODELO: "+
                      str(item.DESCR_MARCA_VEICULO)+"<p>PLACA: "+str(item.PLACA_VEICULO)+"<p>DATA OCORRÊNCIA: "+str(item.DATAOCORRENCIA),
                      icon= folium.Icon(color='red', 
                                        prefix='fa', 
                                        icon='fas fa-car'), tooltip=item.CIDADE ))

    

#adicionando cluster
mapa.add_child(cluster)
#adicionando controle dos mapas
folium.LayerControl().add_to(mapa)
#salvar o mapa
mapa.save('Roubo de carros.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7008/3016577177.py in <module>
#       1 #setando configurações iniciais do mapa
# ----> 2 mapa = folium.Map(location=[y,x],
#       3                   zoom_start=7,
#       4                   tiles='OpenStreetMap', alpha=0)
#       5
#
# NameError: name 'y' is not defined
