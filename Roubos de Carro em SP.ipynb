# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import geopandas as gpd
import glob
import folium
import os
from folium.plugins import MarkerCluster
from shapely.geometry import Polygon, Point, LineString, MultiPolygon

# %% [markdown]
# # Importando dados

# %% [markdown]
# * Carregando todos os arquivos de uma só vez e concatenando em um df principal

# %%
path = 'data/'                     
todos_arquivos = glob.glob(os.path.join(path, "*.csv"))    

dfs = (pd.read_csv(arquivo, usecols=['DATAOCORRENCIA', 'PERIDOOCORRENCIA','LOGRADOURO', 'NUMERO', 'CIDADE', 
                                     'UF', 'LATITUDE', 'LONGITUDE', 'PLACA_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO', 
                                     'ANO_MODELO', 'DESCR_TIPO_VEICULO'], 
                   sep=";", decimal=',', encoding='latin1') for arquivo in todos_arquivos)

df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ## Verificando Base de Dados

# %%
#Visualizando as 5 primeiras linhas 
df.head()
# Out:
#   DATAOCORRENCIA PERIDOOCORRENCIA                       LOGRADOURO  NUMERO  \
# 0     31/12/2020          A NOITE  RUA PROCÓPIO BARBOSA DE MIRANDA     128
# 1     31/12/2020          A NOITE    RUA DOUTOR JOSE PEREIRA GOMES    1627
# 2     31/12/2020          A NOITE         AVENIDA GABRIELA MISTRAL      95
# 3     31/12/2020          A NOITE                   RODOVIA SP 324     520
# 4     31/12/2020          A NOITE                 RUA DOCE VITORIA       5
#
#             CIDADE  UF   LATITUDE  LONGITUDE PLACA_VEICULO DESCR_COR_VEICULO  \
# 0  ITAQUAQUECETUBA  SP -23.464688 -46.316572       DRW2B37             Verde
# 1        SÃO PAULO  SP -23.496574 -46.372711       EZP9F19             Cinza
# 2        SÃO PAULO  SP -23.516960 -46.549701       DRL4572            Branco
# 3         CAMPINAS  SP -23.024741 -47.125820       QMU9905             Prata
# 4        SÃO PAULO  SP -23.567778 -46.418146       FAY7731             Prata
#
#        DESCR_MARCA_VEICULO  ANO_MODELO DESCR_TIPO_VEICULO
# 0          YAMAHA/YBR 125K         NaN          MOTOCICLO
# 1      FORD/KA SE 1.0 HA C         NaN          AUTOMOVEL
# 2    RENAULT/KWID ZEN 10MT      2020.0          AUTOMOVEL
# 3          RENAULT/SANDERO         NaN          AUTOMOVEL
# 4  CHEVROLET/ONIX 1.4MT LT      2015.0          AUTOMOVEL

# %%
# Verificando tamanho da base de dados
print('{} Linhas e {} colunas'.format(df.shape[0], df.shape[1]))
# Out:
# 37702 Linhas e 13 colunas

# %%
df.dtypes
# Out:
# DATAOCORRENCIA          object
# PERIDOOCORRENCIA        object
# LOGRADOURO              object
# NUMERO                   int64
# CIDADE                  object
# UF                      object
# LATITUDE               float64
# LONGITUDE              float64
# PLACA_VEICULO           object
# DESCR_COR_VEICULO       object
# DESCR_MARCA_VEICULO     object
# ANO_MODELO             float64
# DESCR_TIPO_VEICULO      object
# dtype: object

# %% [markdown]
# * Alterando os tipos de colunas

# %%
df[['NUMERO', 'ANO_MODELO']] = df[['NUMERO', 'ANO_MODELO']].astype('object')

# %%
df.dtypes
# Out:
# DATAOCORRENCIA          object
# PERIDOOCORRENCIA        object
# LOGRADOURO              object
# NUMERO                  object
# CIDADE                  object
# UF                      object
# LATITUDE               float64
# LONGITUDE              float64
# PLACA_VEICULO           object
# DESCR_COR_VEICULO       object
# DESCR_MARCA_VEICULO     object
# ANO_MODELO              object
# DESCR_TIPO_VEICULO      object
# dtype: object

# %% [markdown]
# * Verificando se há dados faltantes

# %%
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# Quantidade de dados nulos: 48842

# %%
 df.isna().sum()
# Out:
# DATAOCORRENCIA             0
# PERIDOOCORRENCIA           0
# LOGRADOURO                 0
# NUMERO                     0
# CIDADE                     0
# UF                         0
# LATITUDE                   0
# LONGITUDE                  0
# PLACA_VEICULO          10852
# DESCR_COR_VEICULO       9708
# DESCR_MARCA_VEICULO    10665
# ANO_MODELO              7909
# DESCR_TIPO_VEICULO      9708
# dtype: int64

# %% [markdown]
# ### Decisão sobre os dados Ausentes.

# %% [markdown]
# * Como os dados faltantes se tratam de uma informção sobre o veiculo roubado, não faz sentido remover eses dados.
# * Diante disso irei apenas atribuir 'Não informando' a esses dados faltantes.

# %%
df.fillna( 'NÃO INFORMADO', inplace=True)
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# Quantidade de dados nulos: 0

# %% [markdown]
# # Plotando Mapas

# %% [markdown]
# * Carregando dados de geometria que serão usados para plotagem de mapas

# %%
#importando arquivo com a geometria dos estado
uf_sp = gpd.read_file('mapas/ESTADOS/35UFE250GC_SIR.shp')

# %% [markdown]
# ## Transformando DataFrame em GeoDataDrame

# %%
# filtrando apenas a localização
lat_long = list(zip(df.LATITUDE, df.LONGITUDE))
lat_long
# Out:
# [(-23.464688, -46.3165719),
#  (-23.49657433, -46.37271051),
#  (-23.51696043, -46.54970075),
#  (-23.02474138, -47.12582018),
#  (-23.56777787, -46.41814619),
#  (-23.52918892, -46.47812736),
#  (-23.66183562, -46.68918967),
#  (-23.5007773, -46.4068532),
#  (-22.95027249, -47.11010612),
#  (-22.95027249, -47.11010612),
#  (-23.55058685, -46.96160106),
#  (-23.7193468, -46.55188598),
#  (-23.7193468, -46.55188598),
#  (-22.94248343, -47.08920348),
#  (-23.47155653, -46.30783202),
#  (-23.47155653, -46.30783202),
#  (-23.47155653, -46.30783202),
#  (-23.47155653, -46.30783202),
#  (-23.62351565, -46.54033309),
#  (-23.62484027, -47.04726161),
#  (-23.62484027, -47.04726161),
#  (-23.62484027, -47.04726161),
#  (-23.62484027, -47.04726161),
#  (-23.82916501, -46.72206729),
#  (-23.61877235, -46.76573697),
#  (-22.83921673, -47.15588486),
#  (-23.43550906, -46.5752803),
#  (-23.43550906, -46.5752803),
#  (-23.43550906, -46.5752803),
#  (-23.43550906, -46.5752803),
#  (-23.43550906, -46.5752803),
#  (-23.43550906, -46.5752803),
#  (-22.91273734, -47.03629974),
#  (-23.52813939, -46.46506918),
#  (-23.52813939, -46.46506918),
#  (-23.52813939, -46.46506918),
#  (-23.52813939, -46.46506918),
#  (-23.52813939, -46.46506918),
#  (-23.52813939, -46.46506918),
#  (-23.52813939, -46.46506918),
#  (
#  (-23.66055328, -46.4753529),
#  (-23.28905472, -46.58138454),
#  (-23.44291361, -46.75513232),
#  (-23.44195965, -47.05765119),
#  (-23.44195965, -47.05765119),
#  (-23.44195965, -47.05765119),
#  (-23.44195965, -47.05765119),
#  (-23.44594626, -46.58110753),
#  (-23.44953178, -46.50563445),
#  (-22.74118227, -47.62972232),
#  (-22.74118227, -47.62972232),
#  (-22.74118227, -47.62972232),
#  (-22.74118227, -47.62972232),
#  (-21.96473117, -46.8287407),
#  (-23.53575518, -46.8336784),
#  (-23.6587101, -46.701719),
#  (-23.6587101, -46.701719),
#  (-23.6581202, -46.42501959),
#  (-23.07479115, -45.65114204),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.3884779, -46.74198319),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.55031519, -46.80622929),
#  (-23.38553034, -46.74351624),
#  ...]

# %%
#transformando em pontos geometricos
geometry = [Point(x) for x in lat_long]
geometry
# Out:
# [<shapely.geometry.point.Point at 0x1f3b9392850>,
#  <shapely.geometry.point.Point at 0x1f3bc0594c0>,
#  <shapely.geometry.point.Point at 0x1f3a5a041f0>,
#  <shapely.geometry.point.Point at 0x1f3bc0594f0>,
#  <shapely.geometry.point.Point at 0x1f3b9392f70>,
#  <shapely.geometry.point.Point at 0x1f3b9392e50>,
#  <shapely.geometry.point.Point at 0x1f3b9392610>,
#  <shapely.geometry.point.Point at 0x1f3b9392a30>,
#  <shapely.geometry.point.Point at 0x1f3b9392a60>,
#  <shapely.geometry.point.Point at 0x1f3b9392820>,
#  <shapely.geometry.point.Point at 0x1f3b9392970>,
#  <shapely.geometry.point.Point at 0x1f3b9392f40>,
#  <shapely.geometry.point.Point at 0x1f3b9392c70>,
#  <shapely.geometry.point.Point at 0x1f3bc045790>,
#  <shapely.geometry.point.Point at 0x1f3bc045e20>,
#  <shapely.geometry.point.Point at 0x1f3bc045f40>,
#  <shapely.geometry.point.Point at 0x1f3bc0450d0>,
#  <shapely.geometry.point.Point at 0x1f3bc045430>,
#  <shapely.geometry.point.Point at 0x1f3bc045b20>,
#  <shapely.geometry.point.Point at 0x1f3bc0457f0>,
#  <shapely.geometry.point.Point at 0x1f3bc045880>,
#  <shapely.geometry.point.Point at 0x1f3bc0450a0>,
#  <shapely.geometry.point.Point at 0x1f3bc045700>,
#  <shapely.geometry.point.Point at 0x1f3bc045040>,
#  <shapely.geometry.point.Point at 0x1f3bc0453a0>,
#  <shapely.geometry.point.Point at 0x1f3bc045d30>,
#  <shapely.geometry.point.Point at 0x1f3bc045af0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0f10>,
#  <shapely.geometry.point.Point at 0x1f3e28f0970>,
#  <shapely.geometry.point.Point at 0x1f3e28f0850>,
#  <shapely.geometry.point.Point at 0x1f3e28f0d00>,
#  <shapely.geometry.point.Point at 0x1f3e28f0ac0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0ee0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0400>,
#  <shapely.geometry.point.Point at 0x1f3e28f0d60>,
#  <shapely.geometry.point.Point at 0x1f3e28f0f40>,
#  <shapely.geometry.point.Point at 0x1f3e28f0e50>,
#  <shapely.geometry.point.Point at 0x1f3e28f0d90>,
#  <shapely.geometry.point.Point at 0x1f3e28f0f70>,
#  <shapely.geometry.point.Point at 0x1f3e28f0190>,
#  <shapely.geometry.point.Point at 0x1f3e28f0ca0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0c40>,
#  <shapely.geometry.point.Point at 0x1f3e28f0a90>,
#  <shapely.geometry.point.Point at 0x1f3e28f0fd0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0730>,
#  <shapely.geometry.point.Point at 0x1f3e28f0310>,
#  <shapely.geometry.point.Point at 0x1f3e28f0cd0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0eb0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0610>,
#  <shapely.geometry.point.Point at 0x1f3e28f0d30>,
#  <shapely.geometry.point.Point at 0x1f3e28f0df0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0bb0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0be0>,
#  <shapely.geometry.point.Point at 0x1f3a4b69070>,
#  <shapely.geometry.point.Point at 0x1f3bc059250>,
#  <shapely.geometry.point.Point at 0x1f3e28f0880>,
#  <shapely.geometry.point.Point at 0x1f3e28f0940>,
#  <shapely.geometry.point.Point at 0x1f3e28f04f0>,
#  <shapely.geometry.point.Point at 0x1f3e28f0e80>,
#  <shapely.geometry.point.Point at 0x1f3a3474220>,
#  <shapely.geometry.point.Point at 0x1f3a3474f70>,
#  <shapely.geometry.point.Point at 0x1f3a3474af0>,
#  <shapely.geometry.point.Point at 0x1f3a3474c10>,
#  <shapely.geometry.point.Point at 0x1f3997ff670>,
#  <shapely.geometry.point.Point at 0x1f3997ffbb0>,
#  <shapely.geometry.point.Point at 0x1f3bc0370a0>,
#  <shapely.geometry.point.Point at 0x1f3bc0374c0>,
#  <shapely.geometry.point.Point at 0x1f3bc037b80>,
#  <shapely.geometry.point.Point at 0x1f3bc037eb0>,
#  <shapely.geometry.point.Point at 0x1f3bc037be0>,
#  <shapely.geometry.point.Point at 0x1f3bc037ca0>,
#  <shapely.geometry.point.Point at 0x1f3bc037bb0>,
#  <shapely.geometry.point.Point at 0x1f3bc037040>,
#  <shapely.geometry.point.Point at 0x1f3bc037e80>,
#  <shapely.geometry.point.Point at 0x1f3bc037550>,
#  <shapely.geometry.point.Point at 0x1f3bc037520>,
#  <shapely.geometry.point.Point at 0x1f3bc037130>,
#  <shapely.geometry.point.Point at 0x1f3bc037340>,
#  <shapely.geometry.point.Point at 0x1f3bc037070>,
#  <shapely.geometry.point.Point at 0x1f3bc037100>,
#  <shapely.geometry.point.Point at 0x1f3bc037670>,
#  <shapely.geometry.point.Point at 0x1f3bc037f40>,
#  <shapely.geometry.point.Point at 0x1f3bc0371f0>,
#  <shapely.geometry.point.Point at 0x1f3bc037df0>,
#  <shapely.geometry.point.Point at 0x1f3bc037cd0>,
#  <shapely.geometry.point.Point at 0x1f3bc0376a0>,
#  <shapely.geometry.point.Point at 0x1f3bc0371c0>,
#  <shapely.geometry.point.Point at 0x1f3bc037220>,
#  <shapely.geometry.point.Point at 0x1f3bc0370d0>,
#  <shapely.geometry.point.Point at 0x1f3bc037640>,
#  <shapely.geometry.point.Point at 0x1f3bc0376d0>,
#  <shapely.geometry.point.Point at 0x1f3bc0377c0>,
#  <shapely.geometry.point.Point at 0x1f3bc037370>,
#  <shapely.geometry.point.Point at 0x1f3bc037e20>,
#  <shapely.geometry.point.Point at 0x1f3bc037190>,
#  <shapely.geometry.point.Point at 0x1f3bc037b50>,
#  <shapely.geometry.point.Point at 0x1f3bc037d60>,
#  <shapely.geometry.point.Point at 0x1f3bc037580>,
#  <shapely.geometry.point.Point at 0x1f3bc037f10>,
#  <shapely.geometry.point.Point at 0x1f3bc0375e0>,
#  <shapely.geometry.point.Point at 0x1f3bc037790>,
#  <shapely.geometry.point.Point at 0x1f3bc0377f0>,
#  <shapely.geometry.point.Point at 0x1f3bc037820>,
#  <shapely.geometry.point.Point at 0x1f3bc0378b0>,
#  <shapely.geometry.point.Point at 0x1f3bc037c40>,
#  <shapely.geometry.point.Point at 0x1f3bc037880>,
#  <shapely.geometry.point.Point at 0x1f3bc037760>,
#  <shapely.geometry.point.Point at 0x1f3bc037e50>,
#  <shapely.geometry.point.Point at 0x1f3bc0378e0>,
#  <shapely.geometry.point.Point at 0x1f3bc037730>,
#  <shapely.geometry.point.Point at 0x1f3bc037d00>,
#  <shapely.geometry.point.Point at 0x1f3bc037c10>,
#  <shapely.geometry.point.Point at 0x1f3bc037fd0>,
#  <shapely.geometry.point.Point at 0x1f3bc037d90>,
#  <shapely.geometry.point.Point at 0x1f3bc037fa0>,
#  <shapely.geometry.point.Point at 0x1f3bc037f70>,
#  <shapely.geometry.point.Point at 0x1f3bc037ee0>,
#  <shapely.geometry.point.Point at 0x1f3bc037610>,
#  <shapely.geometry.point.Point at 0x1f3bc0375b0>,
#  <shapely.geometry.point.Point at 0x1f3bc037700>,
#  <shapely.geometry.point.Point at 0x1f3bc037dc0>,
#  <shapely.geometry.point.Point at 0x1f3bc037490>,
#  <shapely.geometry.point.Point at 0x1f3bc037310>,
#  <shapely.geometry.point.Point at 0x1f3bc037c70>,
#  <shapely.geometry.point.Point at 0x1f3bc02dd90>,
#  <shapely.geometry.point.Point at 0x1f3bc02dbe0>,
#  <shapely.geometry.point.Point at 0x1f3bc02de20>,
#  <shapely.geometry.point.Point at 0x1f3bc02dc40>,
#  <shapely.geometry.point.Point at 0x1f3bc02df40>,
#  <shapely.geometry.point.Point at 0x1f3bc02dc70>,
#  <shapely.geometry.point.Point at 0x1f3bc02dd30>,
#  <shapely.geometry.point.Point at 0x1f3bc02dca0>,
#  <shapely.geometry.point.Point at 0x1f3bc02df70>,
#  <shapely.geometry.point.Point at 0x1f3bc02dd00>,
#  <shapely.geometry.point.Point at 0x1f3bc02deb0>,
#  <shapely.geometry.point.Point at 0x1f3bc02d9d0>,
#  <shapely.geometry.point.Point at 0x1f3bc02db50>,
#  <shapely.geometry.point.Point at 0x1f3bc02df10>,
#  <shapely.geometry.point.Point at 0x1f3bc02dee0>,
#  <shapely.geometry.point.Point at 0x1f3bc02ddf0>,
#  <shapely.geometry.point.Point at 0x1f3bc02de50>,
#  <shapely.geometry.point.Point at 0x1f3bc02dd60>,
#  <shapely.geometry.point.Point at 0x1f3bc02ddc0>,
#  <shapely.geometry.point.Point at 0x1f3bc02dcd0>,
#  <shapely.geometry.point.Point at 0x1f3bc02de80>,
#  <shapely.geometry.point.Point at 0x1f3bc02da90>,
#  <shapely.geometry.point.Point at 0x1f3e35cb040>,
#  <shapely.geometry.point.Point at 0x1f3e35cb070>,
#  <shapely.geometry.point.Point at 0x1f3e35cb0a0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb0d0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb100>,
#  <shapely.geometry.point.Point at 0x1f3e35cb130>,
#  <shapely.geometry.point.Point at 0x1f3e35cb160>,
#  <shapely.geometry.point.Point at 0x1f3e35cb190>,
#  <shapely.geometry.point.Point at 0x1f3e35cb1c0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb1f0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb220>,
#  <shapely.geometry.point.Point at 0x1f3e35cb250>,
#  <shapely.geometry.point.Point at 0x1f3e35cb280>,
#  <shapely.geometry.point.Point at 0x1f3e35cb2b0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb2e0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb310>,
#  <shapely.geometry.point.Point at 0x1f3e35cb340>,
#  <shapely.geometry.point.Point at 0x1f3e35cb370>,
#  <shapely.geometry.point.Point at 0x1f3e35cb3a0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb3d0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb400>,
#  <shapely.geometry.point.Point at 0x1f3e35cb430>,
#  <shapely.geometry.point.Point at 0x1f3e35cb460>,
#  <shapely.geometry.point.Point at 0x1f3e35cb490>,
#  <shapely.geometry.point.Point at 0x1f3e35cb4c0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb4f0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb520>,
#  <shapely.geometry.point.Point at 0x1f3e35cb550>,
#  <shapely.geometry.point.Point at 0x1f3e35cb580>,
#  <shapely.geometry.point.Point at 0x1f3e35cb5b0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb5e0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb610>,
#  <shapely.geometry.point.Point at 0x1f3e35cb640>,
#  <shapely.geometry.point.Point at 0x1f3e35cb670>,
#  <shapely.geometry.point.Point at 0x1f3e35cb6a0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb6d0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb700>,
#  <shapely.geometry.point.Point at 0x1f3e35cb730>,
#  <shapely.geometry.point.Point at 0x1f3e35cb760>,
#  <shapely.geometry.point.Point at 0x1f3e35cb790>,
#  <shapely.geometry.point.Point at 0x1f3e35cb7c0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb7f0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb820>,
#  <shapely.geometry.point.Point at 0x1f3e35cb850>,
#  <shapely.geometry.point.Point at 0x1f3e35cb880>,
#  <shapely.geometry.point.Point at 0x1f3e35cb8b0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb8e0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb910>,
#  <shapely.geometry.point.Point at 0x1f3e35cb940>,
#  <shapely.geometry.point.Point at 0x1f3e35cb970>,
#  <shapely.geometry.point.Point at 0x1f3e35cb9a0>,
#  <shapely.geometry.point.Point at 0x1f3e35cb9d0>,
#  <shapely.geometry.point.Point at 0x1f3e35cba00>,
#  <shapely.geometry.point.Point at 0x1f3e35cba30>,
#  <shapely.geometry.point.Point at 0x1f3e35cba60>,
#  <shapely.geometry.point.Point at 0x1f3e35cba90>,
#  <shapely.geometry.point.Point at 0x1f3e35cbac0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbaf0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbb20>,
#  <shapely.geometry.point.Point at 0x1f3e35cbb50>,
#  <shapely.geometry.point.Point at 0x1f3e35cbb80>,
#  <shapely.geometry.point.Point at 0x1f3e35cbbe0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbc10>,
#  <shapely.geometry.point.Point at 0x1f3e35cbc40>,
#  <shapely.geometry.point.Point at 0x1f3e35cbc70>,
#  <shapely.geometry.point.Point at 0x1f3e35cbca0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbcd0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbd00>,
#  <shapely.geometry.point.Point at 0x1f3e35cbd30>,
#  <shapely.geometry.point.Point at 0x1f3e35cbd60>,
#  <shapely.geometry.point.Point at 0x1f3e35cbd90>,
#  <shapely.geometry.point.Point at 0x1f3e35cbdc0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbdf0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbe20>,
#  <shapely.geometry.point.Point at 0x1f3e35cbe50>,
#  <shapely.geometry.point.Point at 0x1f3e35cbe80>,
#  <shapely.geometry.point.Point at 0x1f3e35cbeb0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbee0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbf10>,
#  <shapely.geometry.point.Point at 0x1f3e35cbf40>,
#  <shapely.geometry.point.Point at 0x1f3e35cbf70>,
#  <shapely.geometry.point.Point at 0x1f3e35cbfa0>,
#  <shapely.geometry.point.Point at 0x1f3e35cbfd0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4040>,
#  <shapely.geometry.point.Point at 0x1f3e35d4070>,
#  <shapely.geometry.point.Point at 0x1f3e35d40a0>,
#  <shapely.geometry.point.Point at 0x1f3e35d40d0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4100>,
#  <shapely.geometry.point.Point at 0x1f3e35d4130>,
#  <shapely.geometry.point.Point at 0x1f3e35d4160>,
#  <shapely.geometry.point.Point at 0x1f3e35d4190>,
#  <shapely.geometry.point.Point at 0x1f3e35d41c0>,
#  <shapely.geometry.point.Point at 0x1f3e35d41f0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4220>,
#  <shapely.geometry.point.Point at 0x1f3e35d4250>,
#  <shapely.geometry.point.Point at 0x1f3e35d4280>,
#  <shapely.geometry.point.Point at 0x1f3e35d42b0>,
#  <shapely.geometry.point.Point at 0x1f3e35d42e0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4310>,
#  <shapely.geometry.point.Point at 0x1f3e35d4340>,
#  <shapely.geometry.point.Point at 0x1f3e35d4370>,
#  <shapely.geometry.point.Point at 0x1f3e35d43a0>,
#  <shapely.geometry.point.Point at 0x1f3e35d43d0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4400>,
#  <shapely.geometry.point.Point at 0x1f3e35d4430>,
#  <shapely.geometry.point.Point at 0x1f3e35d4460>,
#  <shapely.geometry.point.Point at 0x1f3e35d4490>,
#  <shapely.geometry.point.Point at 0x1f3e35d44c0>,
#  <shapely.geometry.point.Point at 0x1f3e35d44f0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4520>,
#  <shapely.geometry.point.Point at 0x1f3e35d4550>,
#  <shapely.geometry.point.Point at 0x1f3e35d4580>,
#  <shapely.geometry.point.Point at 0x1f3e35d45b0>,
#  <shapely.geometry.point.Point at 0x1f3e35d45e0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4610>,
#  <shapely.geometry.point.Point at 0x1f3e35d4640>,
#  <shapely.geometry.point.Point at 0x1f3e35d4670>,
#  <shapely.geometry.point.Point at 0x1f3e35d46a0>,
#  <shapely.geometry.point.Point at 0x1f3e35d46d0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4700>,
#  <shapely.geometry.point.Point at 0x1f3e35d4730>,
#  <shapely.geometry.point.Point at 0x1f3e35d4760>,
#  <shapely.geometry.point.Point at 0x1f3e35d4790>,
#  <shapely.geometry.point.Point at 0x1f3e35d47c0>,
#  <shapely.geometry.point.Point at 0x1f3e35d47f0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4820>,
#  <shapely.geometry.point.Point at 0x1f3e35d4850>,
#  <shapely.geometry.point.Point at 0x1f3e35d4880>,
#  <shapely.geometry.point.Point at 0x1f3e35d48b0>,
#  <shapely.geometry.point.Point at 0x1f3e35d48e0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4910>,
#  <shapely.geometry.point.Point at 0x1f3e35d4940>,
#  <shapely.geometry.point.Point at 0x1f3e35d4970>,
#  <shapely.geometry.point.Point at 0x1f3e35d49a0>,
#  <shapely.geometry.point.Point at 0x1f3e35d49d0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4a00>,
#  <shapely.geometry.point.Point at 0x1f3e35d4a30>,
#  <shapely.geometry.point.Point at 0x1f3e35d4a60>,
#  <shapely.geometry.point.Point at 0x1f3e35d4a90>,
#  <shapely.geometry.point.Point at 0x1f3e35d4ac0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4af0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4b20>,
#  <shapely.geometry.point.Point at 0x1f3e35d4b50>,
#  <shapely.geometry.point.Point at 0x1f3e35d4b80>,
#  <shapely.geometry.point.Point at 0x1f3e35d4bb0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4be0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4c10>,
#  <shapely.geometry.point.Point at 0x1f3e35d4c40>,
#  <shapely.geometry.point.Point at 0x1f3e35d4c70>,
#  <shapely.geometry.point.Point at 0x1f3e35d4ca0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4cd0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4d00>,
#  <shapely.geometry.point.Point at 0x1f3e35d4d30>,
#  <shapely.geometry.point.Point at 0x1f3e35d4d60>,
#  <shapely.geometry.point.Point at 0x1f3e35d4d90>,
#  <shapely.geometry.point.Point at 0x1f3e35d4dc0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4df0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4e20>,
#  <shapely.geometry.point.Point at 0x1f3e35d4e50>,
#  <shapely.geometry.point.Point at 0x1f3e35d4e80>,
#  <shapely.geometry.point.Point at 0x1f3e35d4eb0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4ee0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4f10>,
#  <shapely.geometry.point.Point at 0x1f3e35d4f40>,
#  <shapely.geometry.point.Point at 0x1f3e35d4f70>,
#  <shapely.geometry.point.Point at 0x1f3e35d4fa0>,
#  <shapely.geometry.point.Point at 0x1f3e35d4fd0>,
#  <shapely.geometry.point.Point at 0x1f3e35db040>,
#  <shapely.geometry.point.Point at 0x1f3e35db070>,
#  <shapely.geometry.point.Point at 0x1f3e35db0a0>,
#  <shapely.geometry.point.Point at 0x1f3e35db0d0>,
#  <shapely.geometry.point.Point at 0x1f3e35db100>,
#  <shapely.geometry.point.Point at 0x1f3e35db130>,
#  <shapely.geometry.point.Point at 0x1f3e35db160>,
#  <shapely.geometry.point.Point at 0x1f3e35db190>,
#  <shapely.geometry.point.Point at 0x1f3e35db1c0>,
#  <shapely.geometry.point.Point at 0x1f3e35db1f0>,
#  <shapely.geometry.point.Point at 0x1f3e35db220>,
#  <shapely.geometry.point.Point at 0x1f3e35db250>,
#  <shapely.geometry.point.Point at 0x1f3e35db280>,
#  <shapely.geometry.point.Point at 0x1f3e35db2b0>,
#  <shapely.geometry.point.Point at 0x1f3e35db2e0>,
#  <shapely.geometry.point.Point at 0x1f3e35db310>,
#  <shapely.geometry.point.Point at 0x1f3bc0592e0>,
#  <shapely.geometry.point.Point at 0x1f3e35db340>,
#  <shapely.geometry.point.Point at 0x1f3e35db370>,
#  <shapely.geometry.point.Point at 0x1f3e35db3a0>,
#  <shapely.geometry.point.Point at 0x1f3e35db3d0>,
#  <shapely.geometry.point.Point at 0x1f3e35db400>,
#  <shapely.geometry.point.Point at 0x1f3e35db430>,
#  <shapely.geometry.point.Point at 0x1f3e35db460>,
#  <shapely.geometry.point.Point at 0x1f3e35db490>,
#  <shapely.geometry.point.Point at 0x1f3e35db4c0>,
#  <shapely.geometry.point.Point at 0x1f3e35db4f0>,
#  <shapely.geometry.point.Point at 0x1f3e35db520>,
#  <shapely.geometry.point.Point at 0x1f3e35db550>,
#  <shapely.geometry.point.Point at 0x1f3e35db580>,
#  <shapely.geometry.point.Point at 0x1f3e35db5b0>,
#  <shapely.geometry.point.Point at 0x1f3e35db5e0>,
#  <shapely.geometry.point.Point at 0x1f3e35db610>,
#  <shapely.geometry.point.Point at 0x1f3e35db640>,
#  <shapely.geometry.point.Point at 0x1f3e35db670>,
#  <shapely.geometry.point.Point at 0x1f3e35db6a0>,
#  <shapely.geometry.point.Point at 0x1f3e35db6d0>,
#  <shapely.geometry.point.Point at 0x1f3e35db700>,
#  <shapely.geometry.point.Point at 0x1f3e35db730>,
#  <shapely.geometry.point.Point at 0x1f3e35db760>,
#  <shapely.geometry.point.Point at 0x1f3e35db790>,
#  <shapely.geometry.point.Point at 0x1f3e35db7c0>,
#  <shapely.geometry.point.Point at 0x1f3e35db7f0>,
#  <shapely.geometry.point.Point at 0x1f3e35db820>,
#  <shapely.geometry.point.Point at 0x1f3e35db850>,
#  <shapely.geometry.point.Point at 0x1f3e35db880>,
#  <shapely.geometry.point.Point at 0x1f3e35db8b0>,
#  <shapely.geometry.point.Point at 0x1f3e35db8e0>,
#  <shapely.geometry.point.Point at 0x1f3e35db910>,
#  <shapely.geometry.point.Point at 0x1f3e35db940>,
#  <shapely.geometry.point.Point at 0x1f3e35db970>,
#  <shapely.geometry.point.Point at 0x1f3e35db9a0>,
#  <shapely.geometry.point.Point at 0x1f3e35db9d0>,
#  <shapely.geometry.point.Point at 0x1f3e35dba00>,
#  <shapely.geometry.point.Point at 0x1f3e35dba30>,
#  <shapely.geometry.point.Point at 0x1f3e35dba60>,
#  <shapely.geometry.point.Point at 0x1f3e35dba90>,
#  <shapely.geometry.point.Point at 0x1f3e35dbac0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbaf0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbb20>,
#  <shapely.geometry.point.Point at 0x1f3e35dbb50>,
#  <shapely.geometry.point.Point at 0x1f3e35dbb80>,
#  <shapely.geometry.point.Point at 0x1f3e35dbbb0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbbe0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbc10>,
#  <shapely.geometry.point.Point at 0x1f3e35dbc40>,
#  <shapely.geometry.point.Point at 0x1f3e35dbc70>,
#  <shapely.geometry.point.Point at 0x1f3e35dbca0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbcd0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbd00>,
#  <shapely.geometry.point.Point at 0x1f3e35dbd30>,
#  <shapely.geometry.point.Point at 0x1f3e35dbd60>,
#  <shapely.geometry.point.Point at 0x1f3e35dbd90>,
#  <shapely.geometry.point.Point at 0x1f3e35dbdc0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbdf0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbe20>,
#  <shapely.geometry.point.Point at 0x1f3e35dbe50>,
#  <shapely.geometry.point.Point at 0x1f3e35dbe80>,
#  <shapely.geometry.point.Point at 0x1f3e35dbeb0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbee0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbf10>,
#  <shapely.geometry.point.Point at 0x1f3e35dbf40>,
#  <shapely.geometry.point.Point at 0x1f3e35dbf70>,
#  <shapely.geometry.point.Point at 0x1f3e35dbfa0>,
#  <shapely.geometry.point.Point at 0x1f3e35dbfd0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0040>,
#  <shapely.geometry.point.Point at 0x1f3e35e0070>,
#  <shapely.geometry.point.Point at 0x1f3e35e00a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e00d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0100>,
#  <shapely.geometry.point.Point at 0x1f3e35e0130>,
#  <shapely.geometry.point.Point at 0x1f3e35e0160>,
#  <shapely.geometry.point.Point at 0x1f3e35e0190>,
#  <shapely.geometry.point.Point at 0x1f3e35e01c0>,
#  <shapely.geometry.point.Point at 0x1f3e35e01f0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0220>,
#  <shapely.geometry.point.Point at 0x1f3e35e0250>,
#  <shapely.geometry.point.Point at 0x1f3e35e0280>,
#  <shapely.geometry.point.Point at 0x1f3e35e02b0>,
#  <shapely.geometry.point.Point at 0x1f3e35e02e0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0310>,
#  <shapely.geometry.point.Point at 0x1f3e35e0340>,
#  <shapely.geometry.point.Point at 0x1f3e35e0370>,
#  <shapely.geometry.point.Point at 0x1f3e35e03a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e03d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0400>,
#  <shapely.geometry.point.Point at 0x1f3e35e0430>,
#  <shapely.geometry.point.Point at 0x1f3e35e0460>,
#  <shapely.geometry.point.Point at 0x1f3e35e0490>,
#  <shapely.geometry.point.Point at 0x1f3e35e04c0>,
#  <shapely.geometry.point.Point at 0x1f3e35e04f0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0520>,
#  <shapely.geometry.point.Point at 0x1f3e35e0550>,
#  <shapely.geometry.point.Point at 0x1f3e35e0580>,
#  <shapely.geometry.point.Point at 0x1f3e35e05b0>,
#  <shapely.geometry.point.Point at 0x1f3e35e05e0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0610>,
#  <shapely.geometry.point.Point at 0x1f3e35e0640>,
#  <shapely.geometry.point.Point at 0x1f3e35e0670>,
#  <shapely.geometry.point.Point at 0x1f3e35e06a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e06d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0700>,
#  <shapely.geometry.point.Point at 0x1f3e35e0730>,
#  <shapely.geometry.point.Point at 0x1f3e35e0760>,
#  <shapely.geometry.point.Point at 0x1f3e35e0790>,
#  <shapely.geometry.point.Point at 0x1f3e35e07c0>,
#  <shapely.geometry.point.Point at 0x1f3e35e07f0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0820>,
#  <shapely.geometry.point.Point at 0x1f3e35e0850>,
#  <shapely.geometry.point.Point at 0x1f3e35e0880>,
#  <shapely.geometry.point.Point at 0x1f3e35e08b0>,
#  <shapely.geometry.point.Point at 0x1f3e35e08e0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0910>,
#  <shapely.geometry.point.Point at 0x1f3e35e0940>,
#  <shapely.geometry.point.Point at 0x1f3e35e0970>,
#  <shapely.geometry.point.Point at 0x1f3e35e09a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e09d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0a00>,
#  <shapely.geometry.point.Point at 0x1f3e35e0a30>,
#  <shapely.geometry.point.Point at 0x1f3e35e0a60>,
#  <shapely.geometry.point.Point at 0x1f3e35e0a90>,
#  <shapely.geometry.point.Point at 0x1f3e35e0ac0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0af0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0b20>,
#  <shapely.geometry.point.Point at 0x1f3e35e0b50>,
#  <shapely.geometry.point.Point at 0x1f3e35e0b80>,
#  <shapely.geometry.point.Point at 0x1f3e35e0bb0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0be0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0c10>,
#  <shapely.geometry.point.Point at 0x1f3e35e0c40>,
#  <shapely.geometry.point.Point at 0x1f3e35e0c70>,
#  <shapely.geometry.point.Point at 0x1f3e35e0ca0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0cd0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0d00>,
#  <shapely.geometry.point.Point at 0x1f3e35e0d30>,
#  <shapely.geometry.point.Point at 0x1f3e35e0d60>,
#  <shapely.geometry.point.Point at 0x1f3e35e0d90>,
#  <shapely.geometry.point.Point at 0x1f3e35e0dc0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0df0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0e20>,
#  <shapely.geometry.point.Point at 0x1f3e35e0e50>,
#  <shapely.geometry.point.Point at 0x1f3e35e0e80>,
#  <shapely.geometry.point.Point at 0x1f3e35e0eb0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0ee0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0f10>,
#  <shapely.geometry.point.Point at 0x1f3e35e0f40>,
#  <shapely.geometry.point.Point at 0x1f3e35e0f70>,
#  <shapely.geometry.point.Point at 0x1f3e35e0fa0>,
#  <shapely.geometry.point.Point at 0x1f3e35e0fd0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7040>,
#  <shapely.geometry.point.Point at 0x1f3e35e7070>,
#  <shapely.geometry.point.Point at 0x1f3e35e70a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e70d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7100>,
#  <shapely.geometry.point.Point at 0x1f3e35e7130>,
#  <shapely.geometry.point.Point at 0x1f3e35e7160>,
#  <shapely.geometry.point.Point at 0x1f3e35e7190>,
#  <shapely.geometry.point.Point at 0x1f3e35e71c0>,
#  <shapely.geometry.point.Point at 0x1f3e35e71f0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7220>,
#  <shapely.geometry.point.Point at 0x1f3e35e7250>,
#  <shapely.geometry.point.Point at 0x1f3e35e7280>,
#  <shapely.geometry.point.Point at 0x1f3e35e72b0>,
#  <shapely.geometry.point.Point at 0x1f3e35e72e0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7310>,
#  <shapely.geometry.point.Point at 0x1f3e35e7340>,
#  <shapely.geometry.point.Point at 0x1f3e35e7370>,
#  <shapely.geometry.point.Point at 0x1f3e35e73a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e73d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7400>,
#  <shapely.geometry.point.Point at 0x1f3e35e7430>,
#  <shapely.geometry.point.Point at 0x1f3e35e7460>,
#  <shapely.geometry.point.Point at 0x1f3e35e7490>,
#  <shapely.geometry.point.Point at 0x1f3e35e74c0>,
#  <shapely.geometry.point.Point at 0x1f3e35e74f0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7520>,
#  <shapely.geometry.point.Point at 0x1f3e35e7550>,
#  <shapely.geometry.point.Point at 0x1f3e35e7580>,
#  <shapely.geometry.point.Point at 0x1f3e35e75b0>,
#  <shapely.geometry.point.Point at 0x1f3e35e75e0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7610>,
#  <shapely.geometry.point.Point at 0x1f3e35e7640>,
#  <shapely.geometry.point.Point at 0x1f3e35e7670>,
#  <shapely.geometry.point.Point at 0x1f3e35e76a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e76d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7700>,
#  <shapely.geometry.point.Point at 0x1f3e35e7730>,
#  <shapely.geometry.point.Point at 0x1f3e35e7760>,
#  <shapely.geometry.point.Point at 0x1f3e35e7790>,
#  <shapely.geometry.point.Point at 0x1f3e35e77c0>,
#  <shapely.geometry.point.Point at 0x1f3e35e77f0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7820>,
#  <shapely.geometry.point.Point at 0x1f3e35e7850>,
#  <shapely.geometry.point.Point at 0x1f3e35e7880>,
#  <shapely.geometry.point.Point at 0x1f3e35e78b0>,
#  <shapely.geometry.point.Point at 0x1f3e35e78e0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7910>,
#  <shapely.geometry.point.Point at 0x1f3e35e7940>,
#  <shapely.geometry.point.Point at 0x1f3e35e7970>,
#  <shapely.geometry.point.Point at 0x1f3e35e79a0>,
#  <shapely.geometry.point.Point at 0x1f3e35e79d0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7a00>,
#  <shapely.geometry.point.Point at 0x1f3e35e7a30>,
#  <shapely.geometry.point.Point at 0x1f3e35e7a60>,
#  <shapely.geometry.point.Point at 0x1f3e35e7a90>,
#  <shapely.geometry.point.Point at 0x1f3e35e7ac0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7af0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7b20>,
#  <shapely.geometry.point.Point at 0x1f3e35e7b50>,
#  <shapely.geometry.point.Point at 0x1f3e35e7b80>,
#  <shapely.geometry.point.Point at 0x1f3e35e7bb0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7be0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7c10>,
#  <shapely.geometry.point.Point at 0x1f3e35e7c40>,
#  <shapely.geometry.point.Point at 0x1f3e35e7c70>,
#  <shapely.geometry.point.Point at 0x1f3e35e7ca0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7cd0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7d00>,
#  <shapely.geometry.point.Point at 0x1f3e35e7d30>,
#  <shapely.geometry.point.Point at 0x1f3e35e7d60>,
#  <shapely.geometry.point.Point at 0x1f3e35e7d90>,
#  <shapely.geometry.point.Point at 0x1f3e35e7dc0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7df0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7e20>,
#  <shapely.geometry.point.Point at 0x1f3e35e7e50>,
#  <shapely.geometry.point.Point at 0x1f3e35e7e80>,
#  <shapely.geometry.point.Point at 0x1f3e35e7eb0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7ee0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7f10>,
#  <shapely.geometry.point.Point at 0x1f3e35e7f40>,
#  <shapely.geometry.point.Point at 0x1f3e35e7f70>,
#  <shapely.geometry.point.Point at 0x1f3e35e7fa0>,
#  <shapely.geometry.point.Point at 0x1f3e35e7fd0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef040>,
#  <shapely.geometry.point.Point at 0x1f3e35ef070>,
#  <shapely.geometry.point.Point at 0x1f3e35ef0a0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef0d0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef100>,
#  <shapely.geometry.point.Point at 0x1f3e35ef130>,
#  <shapely.geometry.point.Point at 0x1f3e35ef160>,
#  <shapely.geometry.point.Point at 0x1f3e35ef190>,
#  <shapely.geometry.point.Point at 0x1f3e35ef1c0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef1f0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef220>,
#  <shapely.geometry.point.Point at 0x1f3e35ef250>,
#  <shapely.geometry.point.Point at 0x1f3e35ef280>,
#  <shapely.geometry.point.Point at 0x1f3e35ef2b0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef2e0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef310>,
#  <shapely.geometry.point.Point at 0x1f3e35ef340>,
#  <shapely.geometry.point.Point at 0x1f3e35ef370>,
#  <shapely.geometry.point.Point at 0x1f3e35ef3a0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef3d0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef400>,
#  <shapely.geometry.point.Point at 0x1f3e35ef430>,
#  <shapely.geometry.point.Point at 0x1f3e35ef460>,
#  <shapely.geometry.point.Point at 0x1f3e35ef490>,
#  <shapely.geometry.point.Point at 0x1f3e35ef4c0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef4f0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef520>,
#  <shapely.geometry.point.Point at 0x1f3e35ef550>,
#  <shapely.geometry.point.Point at 0x1f3e35ef580>,
#  <shapely.geometry.point.Point at 0x1f3e35ef5b0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef5e0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef610>,
#  <shapely.geometry.point.Point at 0x1f3e35ef640>,
#  <shapely.geometry.point.Point at 0x1f3e35ef670>,
#  <shapely.geometry.point.Point at 0x1f3e35ef6a0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef6d0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef700>,
#  <shapely.geometry.point.Point at 0x1f3e35ef730>,
#  <shapely.geometry.point.Point at 0x1f3e35ef760>,
#  <shapely.geometry.point.Point at 0x1f3e35ef790>,
#  <shapely.geometry.point.Point at 0x1f3e35ef7c0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef7f0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef820>,
#  <shapely.geometry.point.Point at 0x1f3e35ef850>,
#  <shapely.geometry.point.Point at 0x1f3e35ef880>,
#  <shapely.geometry.point.Point at 0x1f3e35ef8b0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef8e0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef910>,
#  <shapely.geometry.point.Point at 0x1f3e35ef940>,
#  <shapely.geometry.point.Point at 0x1f3e35ef970>,
#  <shapely.geometry.point.Point at 0x1f3e35ef9a0>,
#  <shapely.geometry.point.Point at 0x1f3e35ef9d0>,
#  <shapely.geometry.point.Point at 0x1f3e35efa00>,
#  <shapely.geometry.point.Point at 0x1f3e35efa30>,
#  <shapely.geometry.point.Point at 0x1f3e35efa60>,
#  <shapely.geometry.point.Point at 0x1f3e35efa90>,
#  <shapely.geometry.point.Point at 0x1f3e35efac0>,
#  <shapely.geometry.point.Point at 0x1f3e35efaf0>,
#  <shapely.geometry.point.Point at 0x1f3e35efb20>,
#  <shapely.geometry.point.Point at 0x1f3e35efb50>,
#  <shapely.geometry.point.Point at 0x1f3e35efb80>,
#  <shapely.geometry.point.Point at 0x1f3e35efbb0>,
#  <shapely.geometry.point.Point at 0x1f3e35efbe0>,
#  <shapely.geometry.point.Point at 0x1f3e35efc10>,
#  <shapely.geometry.point.Point at 0x1f3e35efc40>,
#  <shapely.geometry.point.Point at 0x1f3e35efc70>,
#  <shapely.geometry.point.Point at 0x1f3e35efca0>,
#  <shapely.geometry.point.Point at 0x1f3e35efcd0>,
#  <shapely.geometry.point.Point at 0x1f3e35efd00>,
#  <shapely.geometry.point.Point at 0x1f3e35efd30>,
#  <shapely.geometry.point.Point at 0x1f3e35efd60>,
#  <shapely.geometry.point.Point at 0x1f3e35efd90>,
#  <shapely.geometry.point.Point at 0x1f3e35efdc0>,
#  <shapely.geometry.point.Point at 0x1f3e35efdf0>,
#  <shapely.geometry.point.Point at 0x1f3e35efe20>,
#  <shapely.geometry.point.Point at 0x1f3e35efe50>,
#  <shapely.geometry.point.Point at 0x1f3e35efe80>,
#  <shapely.geometry.point.Point at 0x1f3e35efeb0>,
#  <shapely.geometry.point.Point at 0x1f3e35efee0>,
#  <shapely.geometry.point.Point at 0x1f3e35eff10>,
#  <shapely.geometry.point.Point at 0x1f3e35eff40>,
#  <shapely.geometry.point.Point at 0x1f3e35eff70>,
#  <shapely.geometry.point.Point at 0x1f3e35effa0>,
#  <shapely.geometry.point.Point at 0x1f3e35effd0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4040>,
#  <shapely.geometry.point.Point at 0x1f3e35f4070>,
#  <shapely.geometry.point.Point at 0x1f3e35f40a0>,
#  <shapely.geometry.point.Point at 0x1f3e35f40d0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4100>,
#  <shapely.geometry.point.Point at 0x1f3e35f4130>,
#  <shapely.geometry.point.Point at 0x1f3e35f4160>,
#  <shapely.geometry.point.Point at 0x1f3e35f4190>,
#  <shapely.geometry.point.Point at 0x1f3e35f41c0>,
#  <shapely.geometry.point.Point at 0x1f3e35f41f0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4220>,
#  <shapely.geometry.point.Point at 0x1f3e35f4250>,
#  <shapely.geometry.point.Point at 0x1f3e35f4280>,
#  <shapely.geometry.point.Point at 0x1f3e35f42b0>,
#  <shapely.geometry.point.Point at 0x1f3e35f42e0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4310>,
#  <shapely.geometry.point.Point at 0x1f3e35f4340>,
#  <shapely.geometry.point.Point at 0x1f3e35f4370>,
#  <shapely.geometry.point.Point at 0x1f3e35f43a0>,
#  <shapely.geometry.point.Point at 0x1f3e35f43d0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4400>,
#  <shapely.geometry.point.Point at 0x1f3e35f4430>,
#  <shapely.geometry.point.Point at 0x1f3e35f4460>,
#  <shapely.geometry.point.Point at 0x1f3e35f4490>,
#  <shapely.geometry.point.Point at 0x1f3e35f44c0>,
#  <shapely.geometry.point.Point at 0x1f3e35f44f0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4520>,
#  <shapely.geometry.point.Point at 0x1f3e35f4550>,
#  <shapely.geometry.point.Point at 0x1f3e35f4580>,
#  <shapely.geometry.point.Point at 0x1f3e35f45b0>,
#  <shapely.geometry.point.Point at 0x1f3e35f45e0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4610>,
#  <shapely.geometry.point.Point at 0x1f3e35f4640>,
#  <shapely.geometry.point.Point at 0x1f3e35f4670>,
#  <shapely.geometry.point.Point at 0x1f3e35f46a0>,
#  <shapely.geometry.point.Point at 0x1f3e35f46d0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4700>,
#  <shapely.geometry.point.Point at 0x1f3e35f4730>,
#  <shapely.geometry.point.Point at 0x1f3e35f4760>,
#  <shapely.geometry.point.Point at 0x1f3e35f4790>,
#  <shapely.geometry.point.Point at 0x1f3e35f47c0>,
#  <shapely.geometry.point.Point at 0x1f3e35f47f0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4820>,
#  <shapely.geometry.point.Point at 0x1f3e35f4850>,
#  <shapely.geometry.point.Point at 0x1f3e35f4880>,
#  <shapely.geometry.point.Point at 0x1f3e35f48b0>,
#  <shapely.geometry.point.Point at 0x1f3e35f48e0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4910>,
#  <shapely.geometry.point.Point at 0x1f3e35f4940>,
#  <shapely.geometry.point.Point at 0x1f3e35f4970>,
#  <shapely.geometry.point.Point at 0x1f3e35f49a0>,
#  <shapely.geometry.point.Point at 0x1f3e35f49d0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4a00>,
#  <shapely.geometry.point.Point at 0x1f3e35f4a30>,
#  <shapely.geometry.point.Point at 0x1f3e35f4a60>,
#  <shapely.geometry.point.Point at 0x1f3e35f4a90>,
#  <shapely.geometry.point.Point at 0x1f3e35f4ac0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4af0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4b20>,
#  <shapely.geometry.point.Point at 0x1f3e35f4b50>,
#  <shapely.geometry.point.Point at 0x1f3e35f4b80>,
#  <shapely.geometry.point.Point at 0x1f3e35f4bb0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4be0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4c10>,
#  <shapely.geometry.point.Point at 0x1f3e35f4c40>,
#  <shapely.geometry.point.Point at 0x1f3e35f4c70>,
#  <shapely.geometry.point.Point at 0x1f3e35f4ca0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4cd0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4d00>,
#  <shapely.geometry.point.Point at 0x1f3e35f4d30>,
#  <shapely.geometry.point.Point at 0x1f3e35f4d60>,
#  <shapely.geometry.point.Point at 0x1f3e35f4d90>,
#  <shapely.geometry.point.Point at 0x1f3e35f4dc0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4df0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4e20>,
#  <shapely.geometry.point.Point at 0x1f3e35f4e50>,
#  <shapely.geometry.point.Point at 0x1f3e35f4e80>,
#  <shapely.geometry.point.Point at 0x1f3e35f4eb0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4ee0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4f10>,
#  <shapely.geometry.point.Point at 0x1f3e35f4f40>,
#  <shapely.geometry.point.Point at 0x1f3e35f4f70>,
#  <shapely.geometry.point.Point at 0x1f3e35f4fa0>,
#  <shapely.geometry.point.Point at 0x1f3e35f4fd0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb040>,
#  <shapely.geometry.point.Point at 0x1f3e35fb070>,
#  <shapely.geometry.point.Point at 0x1f3e35fb0a0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb0d0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb100>,
#  <shapely.geometry.point.Point at 0x1f3e35fb130>,
#  <shapely.geometry.point.Point at 0x1f3e35fb160>,
#  <shapely.geometry.point.Point at 0x1f3e35fb190>,
#  <shapely.geometry.point.Point at 0x1f3e35fb1c0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb1f0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb220>,
#  <shapely.geometry.point.Point at 0x1f3e35fb250>,
#  <shapely.geometry.point.Point at 0x1f3e35fb280>,
#  <shapely.geometry.point.Point at 0x1f3e35fb2b0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb2e0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb310>,
#  <shapely.geometry.point.Point at 0x1f3e35fb340>,
#  <shapely.geometry.point.Point at 0x1f3e35fb370>,
#  <shapely.geometry.point.Point at 0x1f3e35fb3a0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb3d0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb400>,
#  <shapely.geometry.point.Point at 0x1f3e35fb430>,
#  <shapely.geometry.point.Point at 0x1f3e35fb460>,
#  <shapely.geometry.point.Point at 0x1f3e35fb490>,
#  <shapely.geometry.point.Point at 0x1f3e35fb4c0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb4f0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb520>,
#  <shapely.geometry.point.Point at 0x1f3e35fb550>,
#  <shapely.geometry.point.Point at 0x1f3e35fb580>,
#  <shapely.geometry.point.Point at 0x1f3e35fb5b0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb5e0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb610>,
#  <shapely.geometry.point.Point at 0x1f3e35fb640>,
#  <shapely.geometry.point.Point at 0x1f3e35fb670>,
#  <shapely.geometry.point.Point at 0x1f3e35fb6a0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb6d0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb700>,
#  <shapely.geometry.point.Point at 0x1f3e35fb730>,
#  <shapely.geometry.point.Point at 0x1f3e35fb760>,
#  <shapely.geometry.point.Point at 0x1f3e35fb790>,
#  <shapely.geometry.point.Point at 0x1f3e35fb7c0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb7f0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb820>,
#  <shapely.geometry.point.Point at 0x1f3e35fb850>,
#  <shapely.geometry.point.Point at 0x1f3e35fb880>,
#  <shapely.geometry.point.Point at 0x1f3e35fb8b0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb8e0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb910>,
#  <shapely.geometry.point.Point at 0x1f3e35fb940>,
#  <shapely.geometry.point.Point at 0x1f3e35fb970>,
#  <shapely.geometry.point.Point at 0x1f3e35fb9a0>,
#  <shapely.geometry.point.Point at 0x1f3e35fb9d0>,
#  <shapely.geometry.point.Point at 0x1f3e35fba00>,
#  <shapely.geometry.point.Point at 0x1f3e35fba30>,
#  <shapely.geometry.point.Point at 0x1f3e35fba60>,
#  <shapely.geometry.point.Point at 0x1f3e35fba90>,
#  <shapely.geometry.point.Point at 0x1f3e35fbac0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbaf0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbb20>,
#  <shapely.geometry.point.Point at 0x1f3e35fbb50>,
#  <shapely.geometry.point.Point at 0x1f3e35fbb80>,
#  <shapely.geometry.point.Point at 0x1f3e35fbbb0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbbe0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbc10>,
#  <shapely.geometry.point.Point at 0x1f3e35fbc40>,
#  <shapely.geometry.point.Point at 0x1f3e35fbc70>,
#  <shapely.geometry.point.Point at 0x1f3e35fbca0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbcd0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbd00>,
#  <shapely.geometry.point.Point at 0x1f3e35fbd30>,
#  <shapely.geometry.point.Point at 0x1f3e35fbd60>,
#  <shapely.geometry.point.Point at 0x1f3e35fbd90>,
#  <shapely.geometry.point.Point at 0x1f3e35fbdc0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbdf0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbe20>,
#  <shapely.geometry.point.Point at 0x1f3e35fbe50>,
#  <shapely.geometry.point.Point at 0x1f3e35fbe80>,
#  <shapely.geometry.point.Point at 0x1f3e35fbeb0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbee0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbf10>,
#  <shapely.geometry.point.Point at 0x1f3e35fbf40>,
#  <shapely.geometry.point.Point at 0x1f3e35fbf70>,
#  <shapely.geometry.point.Point at 0x1f3e35fbfa0>,
#  <shapely.geometry.point.Point at 0x1f3e35fbfd0>,
#  <shapely.geometry.point.Point at 0x1f3e3602040>,
#  <shapely.geometry.point.Point at 0x1f3e3602070>,
#  <shapely.geometry.point.Point at 0x1f3e36020a0>,
#  <shapely.geometry.point.Point at 0x1f3e36020d0>,
#  <shapely.geometry.point.Point at 0x1f3e3602100>,
#  <shapely.geometry.point.Point at 0x1f3e3602130>,
#  <shapely.geometry.point.Point at 0x1f3e3602160>,
#  <shapely.geometry.point.Point at 0x1f3e3602190>,
#  <shapely.geometry.point.Point at 0x1f3e36021c0>,
#  <shapely.geometry.point.Point at 0x1f3e36021f0>,
#  <shapely.geometry.point.Point at 0x1f3e3602220>,
#  <shapely.geometry.point.Point at 0x1f3e3602250>,
#  <shapely.geometry.point.Point at 0x1f3e3602280>,
#  <shapely.geometry.point.Point at 0x1f3e36022b0>,
#  <shapely.geometry.point.Point at 0x1f3e36022e0>,
#  <shapely.geometry.point.Point at 0x1f3e3602310>,
#  <shapely.geometry.point.Point at 0x1f3e3602340>,
#  <shapely.geometry.point.Point at 0x1f3e3602370>,
#  <shapely.geometry.point.Point at 0x1f3e36023a0>,
#  <shapely.geometry.point.Point at 0x1f3e36023d0>,
#  <shapely.geometry.point.Point at 0x1f3e3602400>,
#  <shapely.geometry.point.Point at 0x1f3e3602430>,
#  <shapely.geometry.point.Point at 0x1f3e3602460>,
#  <shapely.geometry.point.Point at 0x1f3e3602490>,
#  <shapely.geometry.point.Point at 0x1f3e36024c0>,
#  <shapely.geometry.point.Point at 0x1f3e36024f0>,
#  <shapely.geometry.point.Point at 0x1f3e3602520>,
#  <shapely.geometry.point.Point at 0x1f3e3602550>,
#  <shapely.geometry.point.Point at 0x1f3e3602580>,
#  <shapely.geometry.point.Point at 0x1f3e36025b0>,
#  <shapely.geometry.point.Point at 0x1f3e36025e0>,
#  <shapely.geometry.point.Point at 0x1f3e3602610>,
#  <shapely.geometry.point.Point at 0x1f3e3602640>,
#  <shapely.geometry.point.Point at 0x1f3e3602670>,
#  <shapely.geometry.point.Point at 0x1f3e36026a0>,
#  <shapely.geometry.point.Point at 0x1f3e36026d0>,
#  <shapely.geometry.point.Point at 0x1f3e3602700>,
#  <shapely.geometry.point.Point at 0x1f3e3602730>,
#  <shapely.geometry.point.Point at 0x1f3e3602760>,
#  <shapely.geometry.point.Point at 0x1f3e3602790>,
#  <shapely.geometry.point.Point at 0x1f3e36027c0>,
#  <shapely.geometry.point.Point at 0x1f3e36027f0>,
#  <shapely.geometry.point.Point at 0x1f3e3602820>,
#  <shapely.geometry.point.Point at 0x1f3e3602850>,
#  <shapely.geometry.point.Point at 0x1f3e3602880>,
#  <shapely.geometry.point.Point at 0x1f3e36028b0>,
#  <shapely.geometry.point.Point at 0x1f3e36028e0>,
#  <shapely.geometry.point.Point at 0x1f3e3602910>,
#  <shapely.geometry.point.Point at 0x1f3e3602940>,
#  <shapely.geometry.point.Point at 0x1f3e3602970>,
#  <shapely.geometry.point.Point at 0x1f3e36029a0>,
#  <shapely.geometry.point.Point at 0x1f3e36029d0>,
#  <shapely.geometry.point.Point at 0x1f3e3602a00>,
#  <shapely.geometry.point.Point at 0x1f3e3602a30>,
#  <shapely.geometry.point.Point at 0x1f3e3602a60>,
#  <shapely.geometry.point.Point at 0x1f3e3602a90>,
#  <shapely.geometry.point.Point at 0x1f3e3602ac0>,
#  <shapely.geometry.point.Point at 0x1f3e3602af0>,
#  <shapely.geometry.point.Point at 0x1f3e3602b20>,
#  <shapely.geometry.point.Point at 0x1f3e3602b50>,
#  <shapely.geometry.point.Point at 0x1f3e3602b80>,
#  <shapely.geometry.point.Point at 0x1f3e3602bb0>,
#  <shapely.geometry.point.Point at 0x1f3e3602be0>,
#  <shapely.geometry.point.Point at 0x1f3e3602c10>,
#  <shapely.geometry.point.Point at 0x1f3e3602c40>,
#  <shapely.geometry.point.Point at 0x1f3e3602c70>,
#  <shapely.geometry.point.Point at 0x1f3e3602ca0>,
#  <shapely.geometry.point.Point at 0x1f3e3602cd0>,
#  <shapely.geometry.point.Point at 0x1f3e3602d00>,
#  <shapely.geometry.point.Point at 0x1f3e3602d30>,
#  <shapely.geometry.point.Point at 0x1f3e3602d60>,
#  <shapely.geometry.point.Point at 0x1f3e3602d90>,
#  <shapely.geometry.point.Point at 0x1f3e3602dc0>,
#  <shapely.geometry.point.Point at 0x1f3e3602df0>,
#  <shapely.geometry.point.Point at 0x1f3e3602e20>,
#  <shapely.geometry.point.Point at 0x1f3e3602e50>,
#  <shapely.geometry.point.Point at 0x1f3e3602e80>,
#  <shapely.geometry.point.Point at 0x1f3e3602eb0>,
#  <shapely.geometry.point.Point at 0x1f3e3602ee0>,
#  <shapely.geometry.point.Point at 0x1f3e3602f10>,
#  <shapely.geometry.point.Point at 0x1f3e3602f40>,
#  <shapely.geometry.point.Point at 0x1f3e3602f70>,
#  <shapely.geometry.point.Point at 0x1f3e3602fa0>,
#  <shapely.geometry.point.Point at 0x1f3e3602fd0>,
#  <shapely.geometry.point.Point at 0x1f3e3608040>,
#  <shapely.geometry.point.Point at 0x1f3e3608070>,
#  <shapely.geometry.point.Point at 0x1f3e36080a0>,
#  <shapely.geometry.point.Point at 0x1f3e36080d0>,
#  <shapely.geometry.point.Point at 0x1f3e3608100>,
#  <shapely.geometry.point.Point at 0x1f3e3608130>,
#  <shapely.geometry.point.Point at 0x1f3e3608160>,
#  <shapely.geometry.point.Point at 0x1f3e3608190>,
#  <shapely.geometry.point.Point at 0x1f3e36081c0>,
#  <shapely.geometry.point.Point at 0x1f3e36081f0>,
#  <shapely.geometry.point.Point at 0x1f3e3608220>,
#  <shapely.geometry.point.Point at 0x1f3e3608250>,
#  <shapely.geometry.point.Point at 0x1f3e3608280>,
#  <shapely.geometry.point.Point at 0x1f3e36082b0>,
#  <shapely.geometry.point.Point at 0x1f3e36082e0>,
#  <shapely.geometry.point.Point at 0x1f3e3608310>,
#  <shapely.geometry.point.Point at 0x1f3e3608340>,
#  <shapely.geometry.point.Point at 0x1f3e3608370>,
#  <shapely.geometry.point.Point at 0x1f3e36083a0>,
#  <shapely.geometry.point.Point at 0x1f3e36083d0>,
#  <shapely.geometry.point.Point at 0x1f3e3608400>,
#  <shapely.geometry.point.Point at 0x1f3e3608430>,
#  <shapely.geometry.point.Point at 0x1f3e3608460>,
#  <shapely.geometry.point.Point at 0x1f3e3608490>,
#  <shapely.geometry.point.Point at 0x1f3e36084c0>,
#  <shapely.geometry.point.Point at 0x1f3e36084f0>,
#  <shapely.geometry.point.Point at 0x1f3e3608520>,
#  <shapely.geometry.point.Point at 0x1f3e3608550>,
#  <shapely.geometry.point.Point at 0x1f3e3608580>,
#  <shapely.geometry.point.Point at 0x1f3e36085b0>,
#  <shapely.geometry.point.Point at 0x1f3e36085e0>,
#  <shapely.geometry.point.Point at 0x1f3e3608610>,
#  <shapely.geometry.point.Point at 0x1f3e3608640>,
#  <shapely.geometry.point.Point at 0x1f3e3608670>,
#  <shapely.geometry.point.Point at 0x1f3e36086a0>,
#  <shapely.geometry.point.Point at 0x1f3e36086d0>,
#  <shapely.geometry.point.Point at 0x1f3e3608700>,
#  <shapely.geometry.point.Point at 0x1f3e3608730>,
#  <shapely.geometry.point.Point at 0x1f3e3608760>,
#  <shapely.geometry.point.Point at 0x1f3e3608790>,
#  <shapely.geometry.point.Point at 0x1f3e36087c0>,
#  <shapely.geometry.point.Point at 0x1f3e36087f0>,
#  <shapely.geometry.point.Point at 0x1f3e3608820>,
#  <shapely.geometry.point.Point at 0x1f3e3608850>,
#  <shapely.geometry.point.Point at 0x1f3e3608880>,
#  <shapely.geometry.point.Point at 0x1f3e36088b0>,
#  <shapely.geometry.point.Point at 0x1f3e36088e0>,
#  <shapely.geometry.point.Point at 0x1f3e3608910>,
#  <shapely.geometry.point.Point at 0x1f3e3608940>,
#  <shapely.geometry.point.Point at 0x1f3e3608970>,
#  <shapely.geometry.point.Point at 0x1f3e36089a0>,
#  <shapely.geometry.point.Point at 0x1f3e36089d0>,
#  <shapely.geometry.point.Point at 0x1f3e3608a00>,
#  <shapely.geometry.point.Point at 0x1f3e3608a30>,
#  <shapely.geometry.point.Point at 0x1f3e3608a60>,
#  <shapely.geometry.point.Point at 0x1f3e3608a90>,
#  <shapely.geometry.point.Point at 0x1f3e3608ac0>,
#  <shapely.geometry.point.Point at 0x1f3e3608af0>,
#  <shapely.geometry.point.Point at 0x1f3e3608b20>,
#  <shapely.geometry.point.Point at 0x1f3e3608b50>,
#  <shapely.geometry.point.Point at 0x1f3e3608b80>,
#  <shapely.geometry.point.Point at 0x1f3e3608bb0>,
#  <shapely.geometry.point.Point at 0x1f3e3608be0>,
#  <shapely.geometry.point.Point at 0x1f3e3608c10>,
#  <shapely.geometry.point.Point at 0x1f3e3608c40>,
#  <shapely.geometry.point.Point at 0x1f3e3608c70>,
#  <shapely.geometry.point.Point at 0x1f3e3608ca0>,
#  <shapely.geometry.point.Point at 0x1f3e3608cd0>,
#  <shapely.geometry.point.Point at 0x1f3e3608d00>,
#  <shapely.geometry.point.Point at 0x1f3e3608d30>,
#  <shapely.geometry.point.Point at 0x1f3e3608d60>,
#  <shapely.geometry.point.Point at 0x1f3e3608d90>,
#  <shapely.geometry.point.Point at 0x1f3e3608dc0>,
#  <shapely.geometry.point.Point at 0x1f3e3608df0>,
#  <shapely.geometry.point.Point at 0x1f3e3608e20>,
#  <shapely.geometry.point.Point at 0x1f3e3608e50>,
#  <shapely.geometry.point.Point at 0x1f3e3608e80>,
#  <shapely.geometry.point.Point at 0x1f3e3608eb0>,
#  <shapely.geometry.point.Point at 0x1f3e3608ee0>,
#  <shapely.geometry.point.Point at 0x1f3e3608f10>,
#  <shapely.geometry.point.Point at 0x1f3e3608f40>,
#  <shapely.geometry.point.Point at 0x1f3e3608f70>,
#  <shapely.geometry.point.Point at 0x1f3e3608fa0>,
#  <shapely.geometry.point.Point at 0x1f3e3608fd0>,
#  <shapely.geometry.point.Point at 0x1f3e360f040>,
#  <shapely.geometry.point.Point at 0x1f3e360f070>,
#  <shapely.geometry.point.Point at 0x1f3e360f0a0>,
#  <shapely.geometry.point.Point at 0x1f3e360f0d0>,
#  <shapely.geometry.point.Point at 0x1f3e360f100>,
#  <shapely.geometry.point.Point at 0x1f3e360f130>,
#  <shapely.geometry.point.Point at 0x1f3e360f160>,
#  <shapely.geometry.point.Point at 0x1f3e360f190>,
#  <shapely.geometry.point.Point at 0x1f3e360f1c0>,
#  <shapely.geometry.point.Point at 0x1f3e360f1f0>,
#  <shapely.geometry.point.Point at 0x1f3e360f220>,
#  <shapely.geometry.point.Point at 0x1f3e360f250>,
#  <shapely.geometry.point.Point at 0x1f3e360f280>,
#  <shapely.geometry.point.Point at 0x1f3e360f2b0>,
#  ...]

# %%
#configurando crs
crs = {'proj': 'latlong', 'ellps': 'WGS84', 'datum': 'WGS84', 'no_defs': True}
# atribuindo dados geometricos a uma nova coluna do df e transformando em um GEODATAFRAME
geo_dados = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
geo_dados.head()
# Out:
#   DATAOCORRENCIA PERIDOOCORRENCIA                       LOGRADOURO  NUMERO  \
# 0     31/12/2020          A NOITE  RUA PROCÓPIO BARBOSA DE MIRANDA     128
# 1     31/12/2020          A NOITE    RUA DOUTOR JOSE PEREIRA GOMES    1627
# 2     31/12/2020          A NOITE         AVENIDA GABRIELA MISTRAL      95
# 3     31/12/2020          A NOITE                   RODOVIA SP 324     520
# 4     31/12/2020          A NOITE                 RUA DOCE VITORIA       5
#
#             CIDADE  UF   LATITUDE  LONGITUDE PLACA_VEICULO DESCR_COR_VEICULO  \
# 0  ITAQUAQUECETUBA  SP -23.464688 -46.316572       DRW2B37             Verde
# 1        SÃO PAULO  SP -23.496574 -46.372711       EZP9F19             Cinza
# 2        SÃO PAULO  SP -23.516960 -46.549701       DRL4572            Branco
# 3         CAMPINAS  SP -23.024741 -47.125820       QMU9905             Prata
# 4        SÃO PAULO  SP -23.567778 -46.418146       FAY7731             Prata
#
#        DESCR_MARCA_VEICULO     ANO_MODELO DESCR_TIPO_VEICULO  \
# 0          YAMAHA/YBR 125K  NÃO INFORMADO          MOTOCICLO
# 1      FORD/KA SE 1.0 HA C  NÃO INFORMADO          AUTOMOVEL
# 2    RENAULT/KWID ZEN 10MT         2020.0          AUTOMOVEL
# 3          RENAULT/SANDERO  NÃO INFORMADO          AUTOMOVEL
# 4  CHEVROLET/ONIX 1.4MT LT         2015.0          AUTOMOVEL
#
#                       geometry
# 0  POINT (-23.46469 -46.31657)
# 1  POINT (-23.49657 -46.37271)
# 2  POINT (-23.51696 -46.54970)
# 3  POINT (-23.02474 -47.12582)
# 4  POINT (-23.56778 -46.41815)

# %%
# Definindo localização inicial do mapa
y = uf_sp.centroid.y.iloc[0]
x = uf_sp.centroid.x.iloc[0]
# Out:
# C:\WINDOWS\TEMP/ipykernel_2388/2687542583.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   y = uf_sp.centroid.y.iloc[0]
# C:\WINDOWS\TEMP/ipykernel_2388/2687542583.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   x = uf_sp.centroid.x.iloc[0]

# %%
#setando configurações iniciais do mapa
mapa = folium.Map(location=[y,x], 
                  zoom_start=7, 
                  tiles='OpenStreetMap', alpha=0)

#adicionando contorno do estado de SP
mapa.choropleth(uf_sp[uf_sp['NM_ESTADO'] == "SÃO PAULO"],
                name='São Paulo',
                line_color='black',
                line_weight=1,
                fill_opacity=0)

#atibuindo nome do marcador
cluster = MarkerCluster(name='Carros Roubados')

#atribuindo os dados de roubos, icone e outras configurações do mapa
for item in geo_dados.itertuples():
    cluster.add_child(
        folium.Marker(location=[item.LATITUDE, item.LONGITUDE],
                      popup="TIPO: "+ str(item.DESCR_TIPO_VEICULO)+"<p>MODELO: "+
                      str(item.DESCR_MARCA_VEICULO)+"<p>PLACA: "+str(item.PLACA_VEICULO)+"<p>DATA OCORRÊNCIA: "+str(item.DATAOCORRENCIA),
                      icon= folium.Icon(color='red', 
                                        prefix='fa', 
                                        icon='fas fa-car'), tooltip=item.CIDADE ))

    

#adicionando cluster
mapa.add_child(cluster)
#adicionando controle dos mapas
folium.LayerControl().add_to(mapa)
#salvar o mapa
mapa.save('Roubo de carros.html')
# Out:
# c:\users\raila\documents\github\roubos de carro em sp\virtual\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
